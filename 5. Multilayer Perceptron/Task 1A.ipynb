# %% [markdown]
# <a href="https://colab.research.google.com/github/abuebayyeh/imperial_eee_machine_learning_course/blob/main/05_ML_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multilayer Perceptron (MLP)
#
#
# ---
#
#
# Multilayer perceptron (MLP) networks are one of the most commonly used networks, they are also considered as feed-forward networks. The development of the back-propagation learning algorithm for determining weights was the main reason behind the popularity of these networks among researchers. As the name suggests, an MLP consists of multiple perceptrons arranged into a number of layers in order to deal with complex problems. A typical MLP consists of an input layer, hidden layer(s) and an output layer. The units (neurons) in each layer are fully connected to the following layer. MLPs are usually described according to the number of neurons and layers used. For example, a 3-5-4 MLP is a two-layer network consisting of an input layer with three inputs, a hidden layer with five neurons and an output layer with four outputs. The figure below represent a 4-layer MLP (Note: the input layer is not counted as a layer).
#
#
# ![nnmlp.png](data:image/png;base64,...)
#
# The feedforward operation is shown in the diagram below. Each neuron multiplies its inputs $a$ with corresponding weights $w$. The activation function $\theta$ is used to add non-linearity to the process and allows it to learn complex data sets (the network is equivalent to one linear transformation without these non-linearities - try to show this!). The activation function is applied after multiplying the weights with the inputs and summing the results.
#
#
# ![nnop.png](data:image/png;base64,...)
#
# Many activation functions can be used in MLP depending on the problem being investigated. In the figure below are some examples of common activation functions.
#
# ![af1.png](data:image/png;base64,...)
#
# ![af2.png](data:image/png;base64,...)
#
# Many forms of cost functions $J$ to measure the error are available as mentioned in the previous tutorials. The objective of this process is to get the optimal set of tunable parameters (weights and biases) that will minimise the cost $J$. Back-propagation and gradient descent are used to apply these optimisation steps in a systematic manner such that the weights and biases are updated using the derivative and chain-rule concepts as described in the equations below.
#
#
# \begin{aligned}
#     \Delta w_i=-\alpha \frac{\partial J}{\partial w_i} \\
#     w_{i}(t+1)=w_i(t)+\Delta w_i
# \end{aligned}
#
#
#
# The hyperparameter $\alpha$ is called the learning rate which is selected before the training takes place. If the value of $\alpha$ is too high, the algorithm may learn faster; however, it may diverge in reaching the minimal value resulting in oscillating behaviour. On the other hand, if the value of $\alpha$ is too small, the learning process will be slow but more stable. Parameter $t$ refers to the number of iterations (equivalent to number of epochs if update is calculated over entire dataset) where the weights are updated. At the start of training, the weights are usually given random values.

# %% [markdown]
# # MNIST Dataset
#
# In this notebook, we will use a common open access dataset called Modified National Institute of Standards and Technology (MNIST) shown in Figure below.
#
# ![mnist.png](data:image/png;base64,...)
#
#
# This data contains 70,000 scanned images of handwritten digits, together with their correct labels. These images are scanned handwriting samples from 250 people, half of whom were US Census Bureau employees, and the other half were high school students. The images are in grayscale format and of size $28\times 28$ pixels each. The labels are in integer format such that each image has the correct corresponding label that describes it as a number from 0 to 9. The MNIST data is divided into two parts. The first part is the training data that contains 60,000 images. The second part is the test data that contains 10,000 images.
#
# ## The code below is from "Python Machine Learning," Sebastian Raschka, Packt Publishing, 2015 (page 356), with modifications.

# %%
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
import sys
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-11-21 21:29:11.654491: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Importing the data from tensoflow library into train and test.
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 3s 0us/step

# %%
# Displaying samples of the 10 classes in this data

fig = plt.figure()
for i in range(10):
    plt.subplot(2, 5, i+1)
    x_y = X_train[y_train == i]
    plt.imshow(x_y[0], cmap='gray', interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()

# %%
# Displaying different samples of the same class.
print("Samples of class 3:")
fig = plt.figure()

for i in range(10):
    plt.subplot(2, 5, i+1)
    x_y = X_train[y_train == 3]
    plt.imshow(x_y[i], cmap='gray', interpolation='none')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
# Out:
# Samples of class 3:

# %% [markdown]
# Before the images are fed to the MLP, they should go through simple pre-processing steps. First, the pixel values are scaled (normalised) to have values between 0 and 1. In order to do that, all the pixel values are divided by 255 (MNIST grayscale images have 256 different gray values, numbered 0 - 255 (8 bits)). This improves learning stability. Secondly, the image should be flattened to a vector format as the MLP takes a vector with each input corresponding to a pixel location.
#
# ![vectorise.png](data:image/png;base64,...)

# %%
print('X_train.shape', X_train.shape)
print('X_test.shape', X_test.shape)
# reshaping the inputs
X_train = X_train.reshape(60000, 28*28) #Flattening it
X_test = X_test.reshape(10000, 28*28) #Flattening it
# normalizing the inputs (-1, 1)
X_train = X_train.astype('float32') / 255 #Mapping/Standardizing
X_test = X_test.astype('float32') / 255 #Mapping/Standardizing
print('X_train reshape:', X_train.shape)
print('X_test reshape:', X_test.shape)
# Out:
# X_train.shape (60000, 28, 28)
# X_test.shape (10000, 28, 28)
# X_train reshape: (60000, 784)
# X_test reshape: (10000, 784)

# %%
# Create a random permutation of indices
num_train_samples = len(X_train)
num_test_samples = len(X_test)

train_indices = np.random.permutation(num_train_samples)
test_indices = np.random.permutation(num_test_samples)

# Shuffle the data using the permutation of indices. Purely shuffling
X_train = X_train[train_indices]
y_train = y_train[train_indices]

X_test = X_test[test_indices]
y_test = y_test[test_indices]

# %% [markdown]
# The MNIST data does not include validation dataset; however, we can use part of the training set for validation as follows:

# %%
#Splitting the data, 

X_valid=X_train[:5000]
y_valid=y_train[:5000]
X_train=X_train[5000:60000]
y_train=y_train[5000:60000]

# %%
class NeuralNetMLP(object):
    """ Feedforward neural network / Multi-layer perceptron classifier.

    Parameters
    ------------
    n_hidden : int (default: 30)
        Number of hidden units.
    l2 : float (default: 0.)
        Lambda value for L2-regularization.
        No regularization if l2=0. (default)
    epochs : int (default: 100)
        Number of passes over the training set.
    alpha : float (default: 0.001)
        Learning rate.
    shuffle : bool (default: True)
        Shuffles training data every epoch if True to prevent circles.
    minibatch_size : int (default: 1)
        Number of training examples per minibatch.
    seed : int (default: None)
        Random seed for initializing weights and shuffling.

    Attributes
    -----------
    eval_ : dict
      Dictionary collecting the cost, training accuracy,
      and validation accuracy for each epoch during training.

    """
    def __init__(self, n_hidden=30,
                 l2=0., epochs=100, alpha=0.001,
                 shuffle=True, minibatch_size=1, seed=None,
                 activation="sigmoid"):

        self.random = np.random.RandomState(seed)
        self.n_hidden = n_hidden
        self.l2 = l2
        self.epochs = epochs
        self.alpha = alpha
        self.shuffle = shuffle
        self.minibatch_size = minibatch_size
        if activation == "sigmoid":
            self.act = self._sigmoid
            self.act_deriv = lambda a_h: a_h * (1. - a_h)

        ##########################################################################
        #### Task 1:
        #### you can continue your code here to use different activation functions.
        #### adjust the previous conditional statments such that you add cases of
        #### other activation functions.
        ##########################################################################


    def _onehot(self, y, n_classes):
        """Encode labels into one-hot representation

        Parameters
        ------------
        y : array, shape = [n_examples]
            Target values.
        n_classes : int
            Number of classes

        Returns
        -----------
        onehot : array, shape = (n_examples, n_labels)

        """
        onehot = np.zeros((n_classes, y.shape[0]))
        for idx, val in enumerate(y.astype(int)):
            onehot[val, idx] = 1.
        return onehot.T

    def _sigmoid(self, z):
        """Compute logistic function (sigmoid)"""
        return 1. / (1. + np.exp(-np.clip(z, -250, 250)))

    def _forward(self, X):
        """Compute forward propagation step"""

        # step 1: net input of hidden layer
        # [n_examples, n_features] dot [n_features, n_hidden]
        # -> [n_examples, n_hidden]
        z_h = np.dot(X, self.w_h) + self.b_h

        # step 2: activation of hidden layer
        a_h = self.act(z_h)

        # step 3: net input of output layer
        # [n_examples, n_hidden] dot [n_hidden, n_classlabels]
        # -> [n_examples, n_classlabels]

        z_out = np.dot(a_h, self.w_out) + self.b_out

        # step 4: activation output layer
        a_out = self._sigmoid(z_out)

        return z_h, a_h, z_out, a_out

    def _compute_cost(self, y_enc, output):
        """Compute cost function.

        Parameters
        ----------
        y_enc : array, shape = (n_examples, n_labels)
            one-hot encoded class labels.
        output : array, shape = [n_examples, n_output_units]
            Activation of the output layer (forward propagation)

        Returns
        ---------
        cost : float
            Regularized cost

        """
        L2_term = (self.l2 *
                   (np.sum(self.w_h ** 2.) +
                    np.sum(self.w_out ** 2.)))

        term1 = -y_enc * (np.log(output))
        term2 = (1. - y_enc) * np.log(1. - output)
        cost = np.sum(term1 - term2) + L2_term

        # If you are applying this cost function to other
        # datasets where activation
        # values maybe become more extreme (closer to zero or 1)
        # you may encounter "ZeroDivisionError"s due to numerical
        # instabilities in Python & NumPy for the current implementation.
        # I.e., the code tries to evaluate log(0), which is undefined.
        # To address this issue, you could add a small constant to the
        # activation values that are passed to the log function.
        #
        # For example:
        #
        # term1 = -y_enc * (np.log(output + 1e-5))
        # term2 = (1. - y_enc) * np.log(1. - output + 1e-5)

        return cost

    def predict(self, X):
        """Predict class labels

        Parameters
        -----------
        X : array, shape = [n_examples, n_features]
            Input layer with original features.

        Returns:
        ----------
        y_pred : array, shape = [n_examples]
            Predicted class labels.

        """
        z_h, a_h, z_out, a_out = self._forward(X)
        y_pred = np.argmax(z_out, axis=1)
        return y_pred

    def fit(self, X_train, y_train, X_valid, y_valid):
        """ Learn weights from training data.

        Parameters
        -----------
        X_train : array, shape = [n_examples, n_features]
            Input layer with original features.
        y_train : array, shape = [n_examples]
            Target class labels.
        X_valid : array, shape = [n_examples, n_features]
            Sample features for validation during training
        y_valid : array, shape = [n_examples]
            Sample labels for validation during training

        Returns:
        ----------
        self

        """
        n_output = np.unique(y_train).shape[0]  # number of class labels
        n_features = X_train.shape[1]

        ########################
        # Weight initialization
        ########################

        # weights for input -> hidden
        self.b_h = np.zeros(self.n_hidden)
        self.w_h = self.random.normal(loc=0.0, scale=0.1,
                                      size=(n_features, self.n_hidden))

        # weights for hidden -> output
        self.b_out = np.zeros(n_output)
        self.w_out = self.random.normal(loc=0.0, scale=0.1,
                                        size=(self.n_hidden, n_output))

        epoch_strlen = len(str(self.epochs))  # for progress formatting
        self.eval_ = {'cost': [], 'train_acc': [], 'valid_acc': []}

        y_train_enc = self._onehot(y_train, n_output)

        # iterate over training epochs
        for i in range(self.epochs):

            # iterate over minibatches
            indices = np.arange(X_train.shape[0])

            if self.shuffle:
                self.random.shuffle(indices)

            for start_idx in range(0, indices.shape[0] - self.minibatch_size +
                                   1, self.minibatch_size):
                batch_idx = indices[start_idx:start_idx + self.minibatch_size]

                # forward propagation
                z_h, a_h, z_out, a_out = self._forward(X_train[batch_idx])

                ##################
                # Backpropagation
                ##################

                # [n_examples, n_classlabels]
                delta_out = a_out - y_train_enc[batch_idx]

                # [n_examples, n_hidden]
                act_derivative_h = self.act_deriv(a_h)

                # [n_examples, n_classlabels] dot [n_classlabels, n_hidden]
                # -> [n_examples, n_hidden]
                delta_h = (np.dot(delta_out, self.w_out.T) *
                           act_derivative_h)

                # [n_features, n_examples] dot [n_examples, n_hidden]
                # -> [n_features, n_hidden]
                grad_w_h = np.dot(X_train[batch_idx].T, delta_h)
                grad_b_h = np.sum(delta_h, axis=0)

                # [n_hidden, n_examples] dot [n_examples, n_classlabels]
                # -> [n_hidden, n_classlabels]
                grad_w_out = np.dot(a_h.T, delta_out)
                grad_b_out = np.sum(delta_out, axis=0)

                # Regularization and weight updates
                delta_w_h = (grad_w_h + self.l2*self.w_h)
                delta_b_h = grad_b_h # bias is not regularized
                self.w_h -= self.alpha * delta_w_h
                self.b_h -= self.alpha * delta_b_h

                delta_w_out = (grad_w_out + self.l2*self.w_out)
                delta_b_out = grad_b_out  # bias is not regularized
                self.w_out -= self.alpha * delta_w_out
                self.b_out -= self.alpha * delta_b_out

            #############
            # Evaluation
            #############

            # Evaluation after each epoch during training
            z_h, a_h, z_out, a_out = self._forward(X_train)

            cost = self._compute_cost(y_enc=y_train_enc,
                                      output=a_out)

            y_train_pred = self.predict(X_train)
            y_valid_pred = self.predict(X_valid)

            train_acc = ((np.sum(y_train == y_train_pred)).astype(np.float) /
                         X_train.shape[0])
            valid_acc = ((np.sum(y_valid == y_valid_pred)).astype(np.float) /
                         X_valid.shape[0])

            print('\r%0*d/%d | Cost: %.2f '
                  '| Train/Valid Acc.: %.2f%%/%.2f%% ' %
                  (epoch_strlen, i+1, self.epochs, cost,
                  train_acc*100, valid_acc*100))
            # sys.stderr.write
            # sys.stderr.flush()

            self.eval_['cost'].append(cost)
            self.eval_['train_acc'].append(train_acc)
            self.eval_['valid_acc'].append(valid_acc)

        return self

# %%
# Executing the algorithm here (it may take some time to execute the code)

n_epochs = 200 # Number of training epochs

# Initialize a NeuralNet MLP
nn = NeuralNetMLP(
    n_hidden=100,
    l2=2,
    epochs=n_epochs,
    alpha=0.0005,
    minibatch_size=100,
    shuffle=True,
    seed=1,
    activation="sigmoid"
)

# Here we use part of the training data for validation such that 55000 data samples for training and the rest 5000
#for validation
nn.fit(
    X_train,
    y_train,
    X_valid,
    y_valid
)
# Out:
# 001/200 | Cost: 104370.60 | Train/Valid Acc.: 78.69%/78.34%
# 002/200 | Cost: 87540.07 | Train/Valid Acc.: 82.26%/81.72%
# 003/200 | Cost: 82592.82 | Train/Valid Acc.: 84.64%/84.38%
# 004/200 | Cost: 80503.65 | Train/Valid Acc.: 84.21%/83.92%
# 005/200 | Cost: 79405.53 | Train/Valid Acc.: 85.40%/85.12%
# 006/200 | Cost: 78944.45 | Train/Valid Acc.: 85.26%/84.94%
# 007/200 | Cost: 78422.87 | Train/Valid Acc.: 86.02%/85.38%
# 008/200 | Cost: 78084.41 | Train/Valid Acc.: 86.42%/85.94%
# 009/200 | Cost: 77745.96 | Train/Valid Acc.: 86.23%/85.62%
# 010/200 | Cost: 77521.16 | Train/Valid Acc.: 86.33%/85.82%
# 011/200 | Cost: 77340.08 | Train/Valid Acc.: 86.00%/85.52%
# 012/200 | Cost: 77257.63 | Train/Valid Acc.: 86.17%/85.82%
# 013/200 | Cost: 77247.72 | Train/Valid Acc.: 86.12%/85.68%
# 014/200 | Cost: 76991.07 | Train/Valid Acc.: 86.29%/85.80%
# 015/200 | Cost: 77035.65 | Train/Valid Acc.: 86.53%/86.18%
# 016/200 | Cost: 76930.09 | Train/Valid Acc.: 86.59%/86.18%
# 017/200 | Cost: 76774.72 | Train/Valid Acc.: 86.01%/85.36%
# 018/200 | Cost: 76716.23 | Train/Valid Acc.: 86.64%/86.34%
# 019/200 | Cost: 76777.44 | Train/Valid Acc.: 86.07%/85.76%
# 020/200 | Cost: 76565.05 | Train/Valid Acc.: 86.27%/85.82%
# 021/200 | Cost: 76577.59 | Train/Valid Acc.: 86.45%/86.02%
# 022/200 | Cost: 76555.34 | Train/Valid Acc.: 86.07%/85.52%
# 023/200 | Cost: 76523.98 | Train/Valid Acc.: 86.24%/85.62%
# 024/200 | Cost: 76581.47 | Train/Valid Acc.: 85.77%/85.66%
# 025/200 | Cost: 76487.49 | Train/Valid Acc.: 86.52%/86.30%
# 026/200 | Cost: 76450.62 | Train/Valid Acc.: 85.73%/85.18%
# 027/200 | Cost: 76373.27 | Train/Valid Acc.: 86.33%/85.94%
# 028/200 | Cost: 76300.60 | Train/Valid Acc.: 86.56%/86.20%
# 029/200 | Cost: 76345.69 | Train/Valid Acc.: 86.57%/86.32%
# 030/200 | Cost: 76385.13 | Train/Valid Acc.: 86.09%/85.72%
# 031/200 | Cost: 76460.35 | Train/Valid Acc.: 86.05%/85.74%
# 032/200 | Cost: 76251.40 | Train/Valid Acc.: 86.11%/85.68%
# 033/200 | Cost: 76139.56 | Train/Valid Acc.: 86.29%/85.88%
# 034/200 | Cost: 76322.42 | Train/Valid Acc.: 86.18%/85.54%
# 035/200 | Cost: 76186.11 | Train/Valid Acc.: 86.19%/85.92%
# 036/200 | Cost: 76169.71 | Train/Valid Acc.: 86.60%/86.22%
# 037/200 | Cost: 76145.83 | Train/Valid Acc.: 86.44%/86.14%
# 038/200 | Cost: 76126.58 | Train/Valid Acc.: 86.33%/85.86%
# 039/200 | Cost: 76135.47 | Train/Valid Acc.: 86.52%/86.22%
# 040/200 | Cost: 76129.22 | Train/Valid Acc.: 86.39%/86.12%
# 041/200 | Cost: 76140.91 | Train/Valid Acc.: 86.55%/86.36%
# 042/200 | Cost: 76072.29 | Train/Valid Acc.: 86.28%/85.78%
# 043/200 | Cost: 76109.99 | Train/Valid Acc.: 86.77%/86.66%
# 044/200 | Cost: 76037.30 | Train/Valid Acc.: 86.54%/86.20%
# 045/200 | Cost: 76086.00 | Train/Valid Acc.: 86.31%/86.00%
# 046/200 | Cost: 76026.06 | Train/Valid Acc.: 86.15%/85.62%
# 047/200 | Cost: 75997.77 | Train/Valid Acc.: 86.64%/86.26%
# 048/200 | Cost: 75961.55 | Train/Valid Acc.: 86.48%/86.16%
# 049/200 | Cost: 76007.71 | Train/Valid Acc.: 85.91%/85.48%
# 050/200 | Cost: 75932.12 | Train/Valid Acc.: 86.51%/86.26%
# 051/200 | Cost: 76173.89 | Train/Valid Acc.: 86.08%/85.76%
# 052/200 | Cost: 75961.35 | Train/Valid Acc.: 86.14%/85.82%
# 053/200 | Cost: 75980.74 | Train/Valid Acc.: 86.56%/86.26%
# 054/200 | Cost: 76000.87 | Train/Valid Acc.: 86.34%/85.68%
# 055/200 | Cost: 75950.57 | Train/Valid Acc.: 86.06%/85.54%
# 056/200 | Cost: 75869.72 | Train/Valid Acc.: 86.02%/85.66%
# 057/200 | Cost: 75955.10 | Train/Valid Acc.: 86.25%/86.18%
# 058/200 | Cost: 75935.87 | Train/Valid Acc.: 86.48%/86.10%
# 059/200 | Cost: 75965.27 | Train/Valid Acc.: 86.49%/86.28%
# 060/200 | Cost: 75860.75 | Train/Valid Acc.: 86.34%/85.96%
# 061/200 | Cost: 76026.24 | Train/Valid Acc.: 85.98%/85.82%
# 062/200 | Cost: 75874.50 | Train/Valid Acc.: 86.21%/85.74%
# 063/200 | Cost: 76003.18 | Train/Valid Acc.: 86.44%/86.42%
# 064/200 | Cost: 75837.40 | Train/Valid Acc.: 86.45%/86.20%
# 065/200 | Cost: 75918.26 | Train/Valid Acc.: 85.93%/85.54%
# 066/200 | Cost: 75899.15 | Train/Valid Acc.: 86.19%/86.08%
# 067/200 | Cost: 75849.49 | Train/Valid Acc.: 86.51%/86.06%
# 068/200 | Cost: 75835.40 | Train/Valid Acc.: 86.53%/86.00%
# 069/200 | Cost: 75900.00 | Train/Valid Acc.: 86.57%/86.48%
# 070/200 | Cost: 75844.10 | Train/Valid Acc.: 86.39%/86.02%
# 071/200 | Cost: 75829.91 | Train/Valid Acc.: 86.42%/86.14%
# 072/200 | Cost: 75903.38 | Train/Valid Acc.: 85.93%/85.54%
# 073/200 | Cost: 75882.38 | Train/Valid Acc.: 86.64%/86.32%
# 074/200 | Cost: 75937.86 | Train/Valid Acc.: 85.69%/85.34%
# 075/200 | Cost: 75806.80 | Train/Valid Acc.: 86.31%/86.14%
# 076/200 | Cost: 75799.72 | Train/Valid Acc.: 86.17%/86.00%
# 077/200 | Cost: 75821.06 | Train/Valid Acc.: 86.39%/85.96%
# 078/200 | Cost: 75893.50 | Train/Valid Acc.: 86.13%/85.70%
# 079/200 | Cost: 75747.88 | Train/Valid Acc.: 86.45%/86.06%
# 080/200 | Cost: 75850.16 | Train/Valid Acc.: 85.81%/85.64%
# 081/200 | Cost: 75929.17 | Train/Valid Acc.: 85.41%/85.18%
# 082/200 | Cost: 75711.24 | Train/Valid Acc.: 86.36%/86.10%
# 083/200 | Cost: 75728.40 | Train/Valid Acc.: 86.55%/86.24%
# 084/200 | Cost: 75879.35 | Train/Valid Acc.: 85.83%/85.20%
# 085/200 | Cost: 75776.14 | Train/Valid Acc.: 86.46%/86.18%
# 086/200 | Cost: 75833.48 | Train/Valid Acc.: 86.30%/85.86%
# 087/200 | Cost: 75809.70 | Train/Valid Acc.: 86.05%/85.76%
# 088/200 | Cost: 75751.77 | Train/Valid Acc.: 86.57%/86.32%
# 089/200 | Cost: 75714.90 | Train/Valid Acc.: 86.12%/85.76%
# 090/200 | Cost: 75685.70 | Train/Valid Acc.: 86.10%/85.80%
# 091/200 | Cost: 75738.09 | Train/Valid Acc.: 86.27%/85.90%
# 092/200 | Cost: 75888.05 | Train/Valid Acc.: 86.38%/86.00%
# 093/200 | Cost: 75769.85 | Train/Valid Acc.: 86.11%/85.72%
# 094/200 | Cost: 75743.30 | Train/Valid Acc.: 86.03%/85.54%
# 095/200 | Cost: 75722.99 | Train/Valid Acc.: 86.29%/86.14%
# 096/200 | Cost: 75771.86 | Train/Valid Acc.: 86.29%/85.94%
# 097/200 | Cost: 75801.74 | Train/Valid Acc.: 86.58%/86.32%
# 098/200 | Cost: 75862.45 | Train/Valid Acc.: 86.39%/85.98%
# 099/200 | Cost: 75726.26 | Train/Valid Acc.: 86.75%/86.48%
# 100/200 | Cost: 75826.69 | Train/Valid Acc.: 86.06%/85.66%
# 101/200 | Cost: 75755.31 | Train/Valid Acc.: 86.03%/85.70%
# 102/200 | Cost: 75700.96 | Train/Valid Acc.: 86.25%/86.08%
# 103/200 | Cost: 75776.35 | Train/Valid Acc.: 86.50%/86.22%
# 104/200 | Cost: 75654.62 | Train/Valid Acc.: 86.52%/86.32%
# 105/200 | Cost: 75697.34 | Train/Valid Acc.: 86.24%/85.76%
# 106/200 | Cost: 75769.59 | Train/Valid Acc.: 86.63%/86.38%
# 107/200 | Cost: 75763.70 | Train/Valid Acc.: 86.47%/86.12%
# 108/200 | Cost: 75737.87 | Train/Valid Acc.: 86.33%/85.94%
# 109/200 | Cost: 75685.41 | Train/Valid Acc.: 86.10%/85.68%
# 110/200 | Cost: 75662.51 | Train/Valid Acc.: 86.40%/86.10%
# 111/200 | Cost: 75745.54 | Train/Valid Acc.: 86.04%/85.54%
# 112/200 | Cost: 75702.64 | Train/Valid Acc.: 86.04%/85.74%
# 113/200 | Cost: 75708.86 | Train/Valid Acc.: 86.50%/86.32%
# 114/200 | Cost: 75686.69 | Train/Valid Acc.: 86.21%/85.88%
# 115/200 | Cost: 75739.63 | Train/Valid Acc.: 86.27%/85.76%
# 116/200 | Cost: 75780.20 | Train/Valid Acc.: 85.96%/85.58%
# 117/200 | Cost: 75810.93 | Train/Valid Acc.: 86.57%/86.18%
# 118/200 | Cost: 75698.28 | Train/Valid Acc.: 86.47%/86.34%
# 119/200 | Cost: 75667.78 | Train/Valid Acc.: 86.51%/86.28%
# 120/200 | Cost: 75671.43 | Train/Valid Acc.: 86.25%/86.04%
# 121/200 | Cost: 75701.38 | Train/Valid Acc.: 85.78%/85.24%
# 122/200 | Cost: 75610.96 | Train/Valid Acc.: 86.46%/86.22%
# 123/200 | Cost: 75613.01 | Train/Valid Acc.: 86.37%/86.04%
# 124/200 | Cost: 75684.09 | Train/Valid Acc.: 86.28%/85.92%
# 125/200 | Cost: 75665.85 | Train/Valid Acc.: 86.51%/86.32%
# 126/200 | Cost: 75699.64 | Train/Valid Acc.: 86.23%/85.88%
# 127/200 | Cost: 75615.34 | Train/Valid Acc.: 86.37%/86.16%
# 128/200 | Cost: 75599.80 | Train/Valid Acc.: 86.38%/86.18%
# 129/200 | Cost: 75628.83 | Train/Valid Acc.: 86.37%/86.14%
# 130/200 | Cost: 75677.35 | Train/Valid Acc.: 86.22%/86.00%
# 131/200 | Cost: 75717.35 | Train/Valid Acc.: 86.11%/85.84%
# 132/200 | Cost: 75692.85 | Train/Valid Acc.: 86.30%/86.22%
# 133/200 | Cost: 75651.38 | Train/Valid Acc.: 86.46%/86.24%
# 134/200 | Cost: 75840.72 | Train/Valid Acc.: 85.63%/84.96%
# 135/200 | Cost: 75674.23 | Train/Valid Acc.: 86.16%/85.76%
# 136/200 | Cost: 75742.14 | Train/Valid Acc.: 86.57%/86.48%
# 137/200 | Cost: 75715.77 | Train/Valid Acc.: 86.02%/85.74%
# 138/200 | Cost: 75720.36 | Train/Valid Acc.: 86.05%/85.62%
# 139/200 | Cost: 75655.79 | Train/Valid Acc.: 86.38%/85.96%
# 140/200 | Cost: 75606.39 | Train/Valid Acc.: 86.21%/85.94%
# 141/200 | Cost: 75661.18 | Train/Valid Acc.: 86.44%/86.24%
# 142/200 | Cost: 75641.01 | Train/Valid Acc.: 86.26%/85.84%
# 143/200 | Cost: 75586.25 | Train/Valid Acc.: 86.38%/85.96%
# 144/200 | Cost: 75737.23 | Train/Valid Acc.: 85.82%/85.30%
# 145/200 | Cost: 75624.77 | Train/Valid Acc.: 86.51%/86.18%
# 146/200 | Cost: 75803.51 | Train/Valid Acc.: 86.42%/86.08%
# 147/200 | Cost: 75638.89 | Train/Valid Acc.: 86.48%/86.14%
# 148/200 | Cost: 75774.43 | Train/Valid Acc.: 86.66%/86.46%
# 149/200 | Cost: 75742.64 | Train/Valid Acc.: 86.17%/85.68%
# 150/200 | Cost: 75674.24 | Train/Valid Acc.: 86.02%/85.62%
# 151/200 | Cost: 75683.47 | Train/Valid Acc.: 86.57%/86.32%
# 152/200 | Cost: 75738.24 | Train/Valid Acc.: 86.57%/86.34%
# 153/200 | Cost: 75675.00 | Train/Valid Acc.: 86.13%/85.78%
# 154/200 | Cost: 75656.23 | Train/Valid Acc.: 86.21%/85.92%
# 155/200 | Cost: 75626.21 | Train/Valid Acc.: 86.07%/85.80%
# 156/200 | Cost: 75640.22 | Train/Valid Acc.: 86.14%/85.54%
# 157/200 | Cost: 75710.61 | Train/Valid Acc.: 86.15%/85.74%
# 158/200 | Cost: 75635.75 | Train/Valid Acc.: 86.00%/85.58%
# 159/200 | Cost: 75647.45 | Train/Valid Acc.: 86.42%/86.08%
# 160/200 | Cost: 75761.57 | Train/Valid Acc.: 86.00%/85.60%
# 161/200 | Cost: 75613.43 | Train/Valid Acc.: 86.49%/86.34%
# 162/200 | Cost: 75724.57 | Train/Valid Acc.: 86.57%/86.40%
# 163/200 | Cost: 75684.42 | Train/Valid Acc.: 86.41%/86.16%
# 164/200 | Cost: 75724.01 | Train/Valid Acc.: 86.01%/85.86%
# 165/200 | Cost: 75619.07 | Train/Valid Acc.: 86.19%/85.96%
# 166/200 | Cost: 75616.40 | Train/Valid Acc.: 86.19%/85.88%
# 167/200 | Cost: 75704.38 | Train/Valid Acc.: 86.05%/85.80%
# 168/200 | Cost: 75707.17 | Train/Valid Acc.: 86.50%/86.28%
# 169/200 | Cost: 75612.43 | Train/Valid Acc.: 86.17%/85.68%
# 170/200 | Cost: 75625.61 | Train/Valid Acc.: 86.52%/86.18%
# 171/200 | Cost: 75688.58 | Train/Valid Acc.: 86.54%/86.38%
# 172/200 | Cost: 75545.42 | Train/Valid Acc.: 86.29%/85.92%
# 173/200 | Cost: 75658.53 | Train/Valid Acc.: 86.28%/86.02%
# 174/200 | Cost: 75715.28 | Train/Valid Acc.: 85.93%/85.24%
# 175/200 | Cost: 75615.76 | Train/Valid Acc.: 86.29%/85.94%
# 176/200 | Cost: 75554.25 | Train/Valid Acc.: 86.34%/85.94%
# 177/200 | Cost: 75634.78 | Train/Valid Acc.: 86.46%/86.20%
# 178/200 | Cost: 75640.16 | Train/Valid Acc.: 86.23%/85.86%
# 179/200 | Cost: 75698.39 | Train/Valid Acc.: 86.13%/85.70%
# 180/200 | Cost: 75616.03 | Train/Valid Acc.: 86.23%/85.88%
# 181/200 | Cost: 75626.16 | Train/Valid Acc.: 86.64%/86.34%
# 182/200 | Cost: 75498.27 | Train/Valid Acc.: 86.32%/86.06%
# 183/200 | Cost: 75642.21 | Train/Valid Acc.: 86.38%/86.18%
# 184/200 | Cost: 75669.12 | Train/Valid Acc.: 86.47%/86.10%
# 185/200 | Cost: 75630.76 | Train/Valid Acc.: 86.14%/85.66%
# 186/200 | Cost: 75676.25 | Train/Valid Acc.: 86.68%/86.58%
# 187/200 | Cost: 75530.67 | Train/Valid Acc.: 86.55%/86.34%
# 188/200 | Cost: 75544.06 | Train/Valid Acc.: 86.13%/85.86%
# 189/200 | Cost: 75683.87 | Train/Valid Acc.: 86.56%/86.32%
# 190/200 | Cost: 75716.84 | Train/Valid Acc.: 86.68%/86.52%
# 191/200 | Cost: 75743.10 | Train/Valid Acc.: 86.49%/86.34%
# 192/200 | Cost: 75581.75 | Train/Valid Acc.: 86.31%/86.12%
# 193/200 | Cost: 75575.50 | Train/Valid Acc.: 86.49%/86.24%
# 194/200 | Cost: 75527.73 | Train/Valid Acc.: 86.33%/86.12%
# 195/200 | Cost: 75556.90 | Train/Valid Acc.: 86.34%/85.92%
# 196/200 | Cost: 75652.10 | Train/Valid Acc.: 86.30%/86.22%
# 197/200 | Cost: 75664.53 | Train/Valid Acc.: 85.94%/85.48%
# 198/200 | Cost: 75689.42 | Train/Valid Acc.: 86.15%/85.88%
# 199/200 | Cost: 75614.69 | Train/Valid Acc.: 86.31%/86.12%
# 200/200 | Cost: 75687.44 | Train/Valid Acc.: 85.87%/85.60%

# %%
# plot the cost vs epochs
plt.plot(range(nn.epochs), nn.eval_['cost'])
plt.ylabel('Cost')
plt.xlabel('Epochs')
plt.show()

# %%
plt.plot(range(nn.epochs), nn.eval_['train_acc'],
         label='Training')
plt.plot(range(nn.epochs), nn.eval_['valid_acc'],
         label='Validation', linestyle='--')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='lower right')
plt.show()

# %%
y_test_pred = nn.predict(X_test)
acc = (np.sum(y_test == y_test_pred)
       .astype(np.float) / X_test.shape[0])

print('Test accuracy: %.2f%%' % (acc * 100))
# Out:
# Test accuracy: 86.93%

# %%
# Plot examples of misclassified images
miscl_img = X_test[y_test != y_test_pred][:25]
correct_lab = y_test[y_test != y_test_pred][:25]
miscl_lab = y_test_pred[y_test != y_test_pred][:25]

fig, ax = plt.subplots(nrows=5, ncols=5, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(25):
    img = miscl_img[i].reshape(28, 28)
    ax[i].imshow(img, cmap='gray', interpolation='nearest')
    ax[i].set_title('%d) t: %d p: %d' % (i+1, correct_lab[i], miscl_lab[i]))

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# Define the NeuralNetMLP class and other necessary code

# ... (NeuralNetMLP class and other code)

# Define l2 values to test
l2_values = [0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10]

# Initialize lists to store results
train_accuracies = []
valid_accuracies = []
test_accuracies = []

# Iterate over l2 values
for i, l2_value in enumerate(l2_values):
    # Create and train the model
    nn = NeuralNetMLP(
        n_hidden=100,
        l2=l2_value,
        epochs=n_epochs,
        alpha=0.0005,
        minibatch_size=100,
        shuffle=True,
        seed=1,
        activation="sigmoid"
    )
    nn.fit(X_train, y_train, X_valid, y_valid)

    # Evaluate accuracy on training, validation, and test sets
    train_acc = np.max(nn.eval_['train_acc'])  # Take the maximum training accuracy
    valid_acc = np.max(nn.eval_['valid_acc'])  # Take the maximum validation accuracy

    y_test_pred = nn.predict(X_test)
    test_acc = (np.sum(y_test == y_test_pred).astype(np.float) / X_test.shape[0])

    # Append results to lists
    train_accuracies.append(train_acc)
    valid_accuracies.append(valid_acc)
    test_accuracies.append(test_acc)

# Plot points with lines connecting them
plt.plot(l2_values, train_accuracies, color='blue', marker='o', label='Training')
plt.plot(l2_values, valid_accuracies, color='orange', marker='o', label='Validation')
plt.plot(l2_values, test_accuracies, color='green', marker='o', label='Test')

# Plotting
plt.xscale('log')  # Use a logarithmic scale for better visualization
plt.xlabel('l2 Value')
plt.ylabel('Accuracy')
plt.title('Accuracy vs l2 Value')
plt.legend()

# Save the graph
plt.savefig('f2.png')  # Save the figure as a PNG file

# Save the data
results = {
    'l2_values': l2_values,
    'train_accuracies': train_accuracies,
    'valid_accuracies': valid_accuracies,
    'test_accuracies': test_accuracies
}

with open('f4', 'wb') as file:
    pickle.dump(results, file)

plt.show()
# Out:
# 001/200 | Cost: 83593.51 | Train/Valid Acc.: 81.58%/81.32%
# 002/200 | Cost: 59974.39 | Train/Valid Acc.: 85.95%/85.78%
# 003/200 | Cost: 50154.04 | Train/Valid Acc.: 88.10%/88.12%
# 004/200 | Cost: 44586.46 | Train/Valid Acc.: 89.08%/88.62%
# 005/200 | Cost: 41052.04 | Train/Valid Acc.: 89.78%/89.46%
# 006/200 | Cost: 38544.84 | Train/Valid Acc.: 90.22%/90.06%
# 007/200 | Cost: 36590.07 | Train/Valid Acc.: 90.57%/90.36%
# 008/200 | Cost: 35023.93 | Train/Valid Acc.: 90.89%/90.60%
# 009/200 | Cost: 33608.12 | Train/Valid Acc.: 91.27%/90.94%
# 010/200 | Cost: 32392.43 | Train/Valid Acc.: 91.56%/91.18%
# 011/200 | Cost: 31378.94 | Train/Valid Acc.: 91.78%/91.30%
# 012/200 | Cost: 30472.01 | Train/Valid Acc.: 92.10%/91.66%
# 013/200 | Cost: 29609.80 | Train/Valid Acc.: 92.26%/92.02%
# 014/200 | Cost: 28790.42 | Train/Valid Acc.: 92.51%/92.02%
# 015/200 | Cost: 28031.36 | Train/Valid Acc.: 92.70%/92.24%
# 016/200 | Cost: 27343.32 | Train/Valid Acc.: 92.89%/92.42%
# 017/200 | Cost: 26742.28 | Train/Valid Acc.: 93.03%/92.52%
# 018/200 | Cost: 26128.50 | Train/Valid Acc.: 93.21%/92.70%
# 019/200 | Cost: 25561.97 | Train/Valid Acc.: 93.33%/92.84%
# 020/200 | Cost: 25059.03 | Train/Valid Acc.: 93.44%/93.00%
# 021/200 | Cost: 24523.40 | Train/Valid Acc.: 93.63%/93.12%
# 022/200 | Cost: 24055.25 | Train/Valid Acc.: 93.72%/93.16%
# 023/200 | Cost: 23607.66 | Train/Valid Acc.: 93.87%/93.32%
# 024/200 | Cost: 23190.85 | Train/Valid Acc.: 93.97%/93.48%
# 025/200 | Cost: 22772.17 | Train/Valid Acc.: 94.10%/93.64%
# 026/200 | Cost: 22407.76 | Train/Valid Acc.: 94.12%/93.54%
# 027/200 | Cost: 21992.53 | Train/Valid Acc.: 94.28%/93.76%
# 028/200 | Cost: 21610.17 | Train/Valid Acc.: 94.39%/93.96%
# 029/200 | Cost: 21275.50 | Train/Valid Acc.: 94.48%/94.06%
# 030/200 | Cost: 20950.02 | Train/Valid Acc.: 94.60%/94.20%
# 031/200 | Cost: 20616.92 | Train/Valid Acc.: 94.70%/94.38%
# 032/200 | Cost: 20296.31 | Train/Valid Acc.: 94.77%/94.44%
# 033/200 | Cost: 20021.88 | Train/Valid Acc.: 94.83%/94.54%
# 034/200 | Cost: 19737.30 | Train/Valid Acc.: 94.91%/94.66%
# 035/200 | Cost: 19453.15 | Train/Valid Acc.: 94.99%/94.78%
# 036/200 | Cost: 19145.49 | Train/Valid Acc.: 95.08%/94.78%
# 037/200 | Cost: 18904.92 | Train/Valid Acc.: 95.17%/94.86%
# 038/200 | Cost: 18636.56 | Train/Valid Acc.: 95.20%/94.88%
# 039/200 | Cost: 18404.02 | Train/Valid Acc.: 95.25%/94.90%
# 040/200 | Cost: 18176.44 | Train/Valid Acc.: 95.31%/94.88%
# 041/200 | Cost: 17910.99 | Train/Valid Acc.: 95.41%/95.10%
# 042/200 | Cost: 17679.26 | Train/Valid Acc.: 95.49%/95.14%
# 043/200 | Cost: 17472.36 | Train/Valid Acc.: 95.53%/95.20%
# 044/200 | Cost: 17257.23 | Train/Valid Acc.: 95.63%/95.14%
# 045/200 | Cost: 17050.84 | Train/Valid Acc.: 95.67%/95.20%
# 046/200 | Cost: 16846.01 | Train/Valid Acc.: 95.69%/95.18%
# 047/200 | Cost: 16638.47 | Train/Valid Acc.: 95.81%/95.26%
# 048/200 | Cost: 16445.31 | Train/Valid Acc.: 95.86%/95.34%
# 049/200 | Cost: 16260.89 | Train/Valid Acc.: 95.89%/95.42%
# 050/200 | Cost: 16074.88 | Train/Valid Acc.: 95.97%/95.42%
# 051/200 | Cost: 15911.88 | Train/Valid Acc.: 96.00%/95.54%
# 052/200 | Cost: 15734.59 | Train/Valid Acc.: 96.07%/95.54%
# 053/200 | Cost: 15561.19 | Train/Valid Acc.: 96.13%/95.62%
# 054/200 | Cost: 15383.74 | Train/Valid Acc.: 96.15%/95.52%
# 055/200 | Cost: 15234.83 | Train/Valid Acc.: 96.19%/95.70%
# 056/200 | Cost: 15044.28 | Train/Valid Acc.: 96.25%/95.74%
# 057/200 | Cost: 14909.22 | Train/Valid Acc.: 96.31%/95.68%
# 058/200 | Cost: 14748.75 | Train/Valid Acc.: 96.35%/95.76%
# 059/200 | Cost: 14601.30 | Train/Valid Acc.: 96.41%/95.76%
# 060/200 | Cost: 14461.49 | Train/Valid Acc.: 96.45%/95.70%
# 061/200 | Cost: 14304.70 | Train/Valid Acc.: 96.48%/95.80%
# 062/200 | Cost: 14189.29 | Train/Valid Acc.: 96.53%/95.96%
# 063/200 | Cost: 14021.97 | Train/Valid Acc.: 96.55%/95.88%
# 064/200 | Cost: 13900.02 | Train/Valid Acc.: 96.60%/95.88%
# 065/200 | Cost: 13794.38 | Train/Valid Acc.: 96.62%/96.00%
# 066/200 | Cost: 13638.24 | Train/Valid Acc.: 96.68%/95.88%
# 067/200 | Cost: 13508.40 | Train/Valid Acc.: 96.74%/95.98%
# 068/200 | Cost: 13393.98 | Train/Valid Acc.: 96.77%/95.94%
# 069/200 | Cost: 13262.83 | Train/Valid Acc.: 96.79%/96.00%
# 070/200 | Cost: 13141.04 | Train/Valid Acc.: 96.81%/96.10%
# 071/200 | Cost: 13030.98 | Train/Valid Acc.: 96.87%/96.08%
# 072/200 | Cost: 12934.55 | Train/Valid Acc.: 96.90%/96.02%
# 073/200 | Cost: 12793.81 | Train/Valid Acc.: 96.93%/96.02%
# 074/200 | Cost: 12690.48 | Train/Valid Acc.: 96.97%/96.04%
# 075/200 | Cost: 12587.27 | Train/Valid Acc.: 96.99%/96.14%
# 076/200 | Cost: 12475.57 | Train/Valid Acc.: 97.05%/96.12%
# 077/200 | Cost: 12387.92 | Train/Valid Acc.: 97.03%/96.12%
# 078/200 | Cost: 12302.10 | Train/Valid Acc.: 97.10%/96.18%
# 079/200 | Cost: 12172.87 | Train/Valid Acc.: 97.14%/96.22%
# 080/200 | Cost: 12070.91 | Train/Valid Acc.: 97.16%/96.16%
# 081/200 | Cost: 11981.72 | Train/Valid Acc.: 97.19%/96.18%
# 082/200 | Cost: 11864.87 | Train/Valid Acc.: 97.21%/96.28%
# 083/200 | Cost: 11782.60 | Train/Valid Acc.: 97.25%/96.28%
# 084/200 | Cost: 11673.28 | Train/Valid Acc.: 97.27%/96.30%
# 085/200 | Cost: 11593.98 | Train/Valid Acc.: 97.30%/96.34%
# 086/200 | Cost: 11499.60 | Train/Valid Acc.: 97.33%/96.32%
# 087/200 | Cost: 11413.13 | Train/Valid Acc.: 97.34%/96.28%
# 088/200 | Cost: 11324.70 | Train/Valid Acc.: 97.37%/96.30%
# 089/200 | Cost: 11247.57 | Train/Valid Acc.: 97.39%/96.32%
# 090/200 | Cost: 11168.57 | Train/Valid Acc.: 97.40%/96.34%
# 091/200 | Cost: 11083.80 | Train/Valid Acc.: 97.43%/96.38%
# 092/200 | Cost: 10996.33 | Train/Valid Acc.: 97.47%/96.40%
# 093/200 | Cost: 10936.95 | Train/Valid Acc.: 97.46%/96.36%
# 094/200 | Cost: 10829.23 | Train/Valid Acc.: 97.52%/96.40%
# 095/200 | Cost: 10746.96 | Train/Valid Acc.: 97.53%/96.40%
# 096/200 | Cost: 10665.02 | Train/Valid Acc.: 97.54%/96.42%
# 097/200 | Cost: 10599.91 | Train/Valid Acc.: 97.58%/96.36%
# 098/200 | Cost: 10519.91 | Train/Valid Acc.: 97.59%/96.48%
# 099/200 | Cost: 10449.69 | Train/Valid Acc.: 97.59%/96.44%
# 100/200 | Cost: 10367.61 | Train/Valid Acc.: 97.64%/96.44%
# 101/200 | Cost: 10338.76 | Train/Valid Acc.: 97.61%/96.44%
# 102/200 | Cost: 10235.46 | Train/Valid Acc.: 97.65%/96.50%
# 103/200 | Cost: 10155.62 | Train/Valid Acc.: 97.67%/96.48%
# 104/200 | Cost: 10082.91 | Train/Valid Acc.: 97.72%/96.50%
# 105/200 | Cost: 10030.25 | Train/Valid Acc.: 97.72%/96.50%
# 106/200 | Cost: 9966.63 | Train/Valid Acc.: 97.73%/96.50%
# 107/200 | Cost: 9901.71 | Train/Valid Acc.: 97.76%/96.50%
# 108/200 | Cost: 9824.71 | Train/Valid Acc.: 97.78%/96.50%
# 109/200 | Cost: 9763.79 | Train/Valid Acc.: 97.80%/96.54%
# 110/200 | Cost: 9690.15 | Train/Valid Acc.: 97.83%/96.52%
# 111/200 | Cost: 9642.99 | Train/Valid Acc.: 97.84%/96.56%
# 112/200 | Cost: 9575.38 | Train/Valid Acc.: 97.84%/96.54%
# 113/200 | Cost: 9503.81 | Train/Valid Acc.: 97.89%/96.52%
# 114/200 | Cost: 9448.13 | Train/Valid Acc.: 97.89%/96.54%
# 115/200 | Cost: 9394.02 | Train/Valid Acc.: 97.92%/96.56%
# 116/200 | Cost: 9336.36 | Train/Valid Acc.: 97.92%/96.56%
# 117/200 | Cost: 9277.17 | Train/Valid Acc.: 97.92%/96.56%
# 118/200 | Cost: 9225.13 | Train/Valid Acc.: 97.98%/96.66%
# 119/200 | Cost: 9159.27 | Train/Valid Acc.: 97.98%/96.64%
# 120/200 | Cost: 9100.68 | Train/Valid Acc.: 98.02%/96.58%
# 121/200 | Cost: 9052.47 | Train/Valid Acc.: 98.01%/96.58%
# 122/200 | Cost: 8990.82 | Train/Valid Acc.: 98.03%/96.64%
# 123/200 | Cost: 8932.07 | Train/Valid Acc.: 98.04%/96.62%
# 124/200 | Cost: 8878.56 | Train/Valid Acc.: 98.07%/96.66%
# 125/200 | Cost: 8832.86 | Train/Valid Acc.: 98.10%/96.70%
# 126/200 | Cost: 8773.19 | Train/Valid Acc.: 98.11%/96.66%
# 127/200 | Cost: 8733.86 | Train/Valid Acc.: 98.13%/96.68%
# 128/200 | Cost: 8677.91 | Train/Valid Acc.: 98.14%/96.64%
# 129/200 | Cost: 8643.43 | Train/Valid Acc.: 98.14%/96.66%
# 130/200 | Cost: 8582.46 | Train/Valid Acc.: 98.16%/96.72%
# 131/200 | Cost: 8527.49 | Train/Valid Acc.: 98.18%/96.70%
# 132/200 | Cost: 8475.89 | Train/Valid Acc.: 98.18%/96.70%
# 133/200 | Cost: 8430.91 | Train/Valid Acc.: 98.19%/96.74%
# 134/200 | Cost: 8380.25 | Train/Valid Acc.: 98.21%/96.74%
# 135/200 | Cost: 8346.51 | Train/Valid Acc.: 98.26%/96.70%
# 136/200 | Cost: 8302.02 | Train/Valid Acc.: 98.25%/96.74%
# 137/200 | Cost: 8263.24 | Train/Valid Acc.: 98.25%/96.68%
# 138/200 | Cost: 8191.20 | Train/Valid Acc.: 98.29%/96.72%
# 139/200 | Cost: 8159.83 | Train/Valid Acc.: 98.29%/96.84%
# 140/200 | Cost: 8103.70 | Train/Valid Acc.: 98.29%/96.78%
# 141/200 | Cost: 8065.26 | Train/Valid Acc.: 98.32%/96.80%
# 142/200 | Cost: 8020.35 | Train/Valid Acc.: 98.33%/96.74%
# 143/200 | Cost: 7977.81 | Train/Valid Acc.: 98.33%/96.84%
# 144/200 | Cost: 7927.12 | Train/Valid Acc.: 98.36%/96.82%
# 145/200 | Cost: 7882.81 | Train/Valid Acc.: 98.37%/96.74%
# 146/200 | Cost: 7846.45 | Train/Valid Acc.: 98.37%/96.78%
# 147/200 | Cost: 7796.89 | Train/Valid Acc.: 98.38%/96.80%
# 148/200 | Cost: 7773.59 | Train/Valid Acc.: 98.41%/96.86%
# 149/200 | Cost: 7722.96 | Train/Valid Acc.: 98.41%/96.90%
# 150/200 | Cost: 7673.75 | Train/Valid Acc.: 98.41%/96.78%
# 151/200 | Cost: 7670.76 | Train/Valid Acc.: 98.41%/96.86%
# 152/200 | Cost: 7597.89 | Train/Valid Acc.: 98.46%/96.90%
# 153/200 | Cost: 7570.78 | Train/Valid Acc.: 98.44%/96.86%
# 154/200 | Cost: 7518.90 | Train/Valid Acc.: 98.44%/96.82%
# 155/200 | Cost: 7480.27 | Train/Valid Acc.: 98.45%/96.92%
# 156/200 | Cost: 7451.93 | Train/Valid Acc.: 98.48%/96.88%
# 157/200 | Cost: 7406.33 | Train/Valid Acc.: 98.48%/96.90%
# 158/200 | Cost: 7364.48 | Train/Valid Acc.: 98.51%/96.94%
# 159/200 | Cost: 7331.83 | Train/Valid Acc.: 98.50%/96.96%
# 160/200 | Cost: 7293.06 | Train/Valid Acc.: 98.51%/96.90%
# 161/200 | Cost: 7259.51 | Train/Valid Acc.: 98.53%/96.98%
# 162/200 | Cost: 7214.74 | Train/Valid Acc.: 98.53%/96.92%
# 163/200 | Cost: 7184.27 | Train/Valid Acc.: 98.54%/97.00%
# 164/200 | Cost: 7146.10 | Train/Valid Acc.: 98.55%/97.04%
# 165/200 | Cost: 7104.79 | Train/Valid Acc.: 98.57%/96.98%
# 166/200 | Cost: 7074.47 | Train/Valid Acc.: 98.56%/97.00%
# 167/200 | Cost: 7041.57 | Train/Valid Acc.: 98.57%/96.98%
# 168/200 | Cost: 7037.80 | Train/Valid Acc.: 98.57%/96.96%
# 169/200 | Cost: 6969.09 | Train/Valid Acc.: 98.59%/97.02%
# 170/200 | Cost: 6941.19 | Train/Valid Acc.: 98.60%/97.00%
# 171/200 | Cost: 6911.49 | Train/Valid Acc.: 98.60%/97.06%
# 172/200 | Cost: 6874.57 | Train/Valid Acc.: 98.61%/97.00%
# 173/200 | Cost: 6834.40 | Train/Valid Acc.: 98.63%/97.02%
# 174/200 | Cost: 6806.86 | Train/Valid Acc.: 98.64%/97.08%
# 175/200 | Cost: 6780.03 | Train/Valid Acc.: 98.64%/97.12%
# 176/200 | Cost: 6738.95 | Train/Valid Acc.: 98.65%/97.06%
# 177/200 | Cost: 6706.60 | Train/Valid Acc.: 98.65%/97.08%
# 178/200 | Cost: 6676.36 | Train/Valid Acc.: 98.67%/97.08%
# 179/200 | Cost: 6642.04 | Train/Valid Acc.: 98.67%/97.04%
# 180/200 | Cost: 6615.31 | Train/Valid Acc.: 98.69%/97.10%
# 181/200 | Cost: 6590.56 | Train/Valid Acc.: 98.69%/97.08%
# 182/200 | Cost: 6568.15 | Train/Valid Acc.: 98.68%/96.98%
# 183/200 | Cost: 6520.79 | Train/Valid Acc.: 98.70%/97.08%
# 184/200 | Cost: 6497.26 | Train/Valid Acc.: 98.72%/97.16%
# 185/200 | Cost: 6457.90 | Train/Valid Acc.: 98.71%/97.10%
# 186/200 | Cost: 6436.52 | Train/Valid Acc.: 98.73%/97.08%
# 187/200 | Cost: 6400.90 | Train/Valid Acc.: 98.74%/97.12%
# 188/200 | Cost: 6376.41 | Train/Valid Acc.: 98.74%/97.14%
# 189/200 | Cost: 6347.20 | Train/Valid Acc.: 98.76%/97.08%
# 190/200 | Cost: 6331.06 | Train/Valid Acc.: 98.77%/97.16%
# 191/200 | Cost: 6285.03 | Train/Valid Acc.: 98.77%/97.16%
# 192/200 | Cost: 6255.95 | Train/Valid Acc.: 98.77%/97.18%
# 193/200 | Cost: 6233.48 | Train/Valid Acc.: 98.77%/97.12%
# 194/200 | Cost: 6206.08 | Train/Valid Acc.: 98.80%/97.26%
# 195/200 | Cost: 6181.40 | Train/Valid Acc.: 98.81%/97.20%
# 196/200 | Cost: 6140.03 | Train/Valid Acc.: 98.81%/97.20%
# 197/200 | Cost: 6119.18 | Train/Valid Acc.: 98.81%/97.12%
# 198/200 | Cost: 6104.53 | Train/Valid Acc.: 98.82%/97.16%
# 199/200 | Cost: 6060.66 | Train/Valid Acc.: 98.83%/97.26%
# 200/200 | Cost: 6036.75 | Train/Valid Acc.: 98.83%/97.20%
# 001/200 | Cost: 83593.60 | Train/Valid Acc.: 81.58%/81.32%
# 002/200 | Cost: 59974.51 | Train/Valid Acc.: 85.95%/85.78%
# 003/200 | Cost: 50154.17 | Train/Valid Acc.: 88.10%/88.12%
# 004/200 | Cost: 44586.61 | Train/Valid Acc.: 89.08%/88.62%
# 005/200 | Cost: 41052.20 | Train/Valid Acc.: 89.78%/89.46%
# 006/200 | Cost: 38545.01 | Train/Valid Acc.: 90.22%/90.06%
# 007/200 | Cost: 36590.26 | Train/Valid Acc.: 90.57%/90.36%
# 008/200 | Cost: 35024.13 | Train/Valid Acc.: 90.89%/90.60%
# 009/200 | Cost: 33608.34 | Train/Valid Acc.: 91.27%/90.94%
# 010/200 | Cost: 32392.66 | Train/Valid Acc.: 91.56%/91.18%
# 011/200 | Cost: 31379.18 | Train/Valid Acc.: 91.78%/91.30%
# 012/200 | Cost: 30472.27 | Train/Valid Acc.: 92.10%/91.66%
# 013/200 | Cost: 29610.08 | Train/Valid Acc.: 92.26%/92.02%
# 014/200 | Cost: 28790.71 | Train/Valid Acc.: 92.51%/92.02%
# 015/200 | Cost: 28031.67 | Train/Valid Acc.: 92.70%/92.24%
# 016/200 | Cost: 27343.64 | Train/Valid Acc.: 92.89%/92.42%
# 017/200 | Cost: 26742.62 | Train/Valid Acc.: 93.03%/92.52%
# 018/200 | Cost: 26128.85 | Train/Valid Acc.: 93.21%/92.70%
# 019/200 | Cost: 25562.33 | Train/Valid Acc.: 93.33%/92.84%
# 020/200 | Cost: 25059.40 | Train/Valid Acc.: 93.44%/93.00%
# 021/200 | Cost: 24523.79 | Train/Valid Acc.: 93.63%/93.12%
# 022/200 | Cost: 24055.65 | Train/Valid Acc.: 93.72%/93.16%
# 023/200 | Cost: 23608.07 | Train/Valid Acc.: 93.87%/93.32%
# 024/200 | Cost: 23191.28 | Train/Valid Acc.: 93.97%/93.48%
# 025/200 | Cost: 22772.61 | Train/Valid Acc.: 94.10%/93.64%
# 026/200 | Cost: 22408.22 | Train/Valid Acc.: 94.12%/93.54%
# 027/200 | Cost: 21992.99 | Train/Valid Acc.: 94.28%/93.76%
# 028/200 | Cost: 21610.64 | Train/Valid Acc.: 94.39%/93.96%
# 029/200 | Cost: 21275.99 | Train/Valid Acc.: 94.48%/94.06%
# 030/200 | Cost: 20950.53 | Train/Valid Acc.: 94.60%/94.20%
# 031/200 | Cost: 20617.43 | Train/Valid Acc.: 94.70%/94.38%
# 032/200 | Cost: 20296.83 | Train/Valid Acc.: 94.77%/94.44%
# 033/200 | Cost: 20022.42 | Train/Valid Acc.: 94.83%/94.54%
# 034/200 | Cost: 19737.85 | Train/Valid Acc.: 94.91%/94.66%
# 035/200 | Cost: 19453.70 | Train/Valid Acc.: 94.99%/94.78%
# 036/200 | Cost: 19146.06 | Train/Valid Acc.: 95.08%/94.78%
# 037/200 | Cost: 18905.50 | Train/Valid Acc.: 95.17%/94.86%
# 038/200 | Cost: 18637.15 | Train/Valid Acc.: 95.20%/94.88%
# 039/200 | Cost: 18404.61 | Train/Valid Acc.: 95.25%/94.90%
# 040/200 | Cost: 18177.05 | Train/Valid Acc.: 95.31%/94.88%
# 041/200 | Cost: 17911.60 | Train/Valid Acc.: 95.41%/95.10%
# 042/200 | Cost: 17679.89 | Train/Valid Acc.: 95.49%/95.14%
# 043/200 | Cost: 17472.99 | Train/Valid Acc.: 95.53%/95.20%
# 044/200 | Cost: 17257.87 | Train/Valid Acc.: 95.63%/95.14%
# 045/200 | Cost: 17051.49 | Train/Valid Acc.: 95.67%/95.20%
# 046/200 | Cost: 16846.67 | Train/Valid Acc.: 95.69%/95.18%
# 047/200 | Cost: 16639.14 | Train/Valid Acc.: 95.81%/95.26%
# 048/200 | Cost: 16445.99 | Train/Valid Acc.: 95.86%/95.34%
# 049/200 | Cost: 16261.58 | Train/Valid Acc.: 95.89%/95.42%
# 050/200 | Cost: 16075.57 | Train/Valid Acc.: 95.97%/95.42%
# 051/200 | Cost: 15912.59 | Train/Valid Acc.: 96.00%/95.54%
# 052/200 | Cost: 15735.31 | Train/Valid Acc.: 96.07%/95.54%
# 053/200 | Cost: 15561.91 | Train/Valid Acc.: 96.13%/95.62%
# 054/200 | Cost: 15384.47 | Train/Valid Acc.: 96.15%/95.52%
# 055/200 | Cost: 15235.57 | Train/Valid Acc.: 96.19%/95.70%
# 056/200 | Cost: 15045.03 | Train/Valid Acc.: 96.25%/95.74%
# 057/200 | Cost: 14909.98 | Train/Valid Acc.: 96.31%/95.68%
# 058/200 | Cost: 14749.51 | Train/Valid Acc.: 96.35%/95.76%
# 059/200 | Cost: 14602.06 | Train/Valid Acc.: 96.41%/95.76%
# 060/200 | Cost: 14462.26 | Train/Valid Acc.: 96.45%/95.70%
# 061/200 | Cost: 14305.49 | Train/Valid Acc.: 96.48%/95.80%
# 062/200 | Cost: 14190.08 | Train/Valid Acc.: 96.53%/95.96%
# 063/200 | Cost: 14022.77 | Train/Valid Acc.: 96.55%/95.88%
# 064/200 | Cost: 13900.83 | Train/Valid Acc.: 96.60%/95.88%
# 065/200 | Cost: 13795.19 | Train/Valid Acc.: 96.62%/96.00%
# 066/200 | Cost: 13639.05 | Train/Valid Acc.: 96.68%/95.88%
# 067/200 | Cost: 13509.22 | Train/Valid Acc.: 96.74%/95.98%
# 068/200 | Cost: 13394.81 | Train/Valid Acc.: 96.77%/95.94%
# 069/200 | Cost: 13263.66 | Train/Valid Acc.: 96.79%/96.00%
# 070/200 | Cost: 13141.88 | Train/Valid Acc.: 96.81%/96.10%
# 071/200 | Cost: 13031.83 | Train/Valid Acc.: 96.87%/96.08%
# 072/200 | Cost: 12935.41 | Train/Valid Acc.: 96.90%/96.02%
# 073/200 | Cost: 12794.67 | Train/Valid Acc.: 96.93%/96.02%
# 074/200 | Cost: 12691.35 | Train/Valid Acc.: 96.97%/96.04%
# 075/200 | Cost: 12588.15 | Train/Valid Acc.: 96.99%/96.14%
# 076/200 | Cost: 12476.46 | Train/Valid Acc.: 97.05%/96.12%
# 077/200 | Cost: 12388.82 | Train/Valid Acc.: 97.03%/96.12%
# 078/200 | Cost: 12303.00 | Train/Valid Acc.: 97.10%/96.18%
# 079/200 | Cost: 12173.77 | Train/Valid Acc.: 97.14%/96.22%
# 080/200 | Cost: 12071.82 | Train/Valid Acc.: 97.16%/96.16%
# 081/200 | Cost: 11982.64 | Train/Valid Acc.: 97.19%/96.18%
# 082/200 | Cost: 11865.79 | Train/Valid Acc.: 97.21%/96.28%
# 083/200 | Cost: 11783.54 | Train/Valid Acc.: 97.25%/96.28%
# 084/200 | Cost: 11674.22 | Train/Valid Acc.: 97.27%/96.30%
# 085/200 | Cost: 11594.93 | Train/Valid Acc.: 97.30%/96.34%
# 086/200 | Cost: 11500.55 | Train/Valid Acc.: 97.33%/96.32%
# 087/200 | Cost: 11414.08 | Train/Valid Acc.: 97.34%/96.28%
# 088/200 | Cost: 11325.66 | Train/Valid Acc.: 97.37%/96.30%
# 089/200 | Cost: 11248.53 | Train/Valid Acc.: 97.39%/96.32%
# 090/200 | Cost: 11169.55 | Train/Valid Acc.: 97.40%/96.34%
# 091/200 | Cost: 11084.77 | Train/Valid Acc.: 97.43%/96.38%
# 092/200 | Cost: 10997.32 | Train/Valid Acc.: 97.47%/96.40%
# 093/200 | Cost: 10937.94 | Train/Valid Acc.: 97.46%/96.36%
# 094/200 | Cost: 10830.22 | Train/Valid Acc.: 97.52%/96.40%
# 095/200 | Cost: 10747.97 | Train/Valid Acc.: 97.53%/96.40%
# 096/200 | Cost: 10666.03 | Train/Valid Acc.: 97.54%/96.42%
# 097/200 | Cost: 10600.93 | Train/Valid Acc.: 97.58%/96.36%
# 098/200 | Cost: 10520.93 | Train/Valid Acc.: 97.59%/96.48%
# 099/200 | Cost: 10450.72 | Train/Valid Acc.: 97.59%/96.44%
# 100/200 | Cost: 10368.64 | Train/Valid Acc.: 97.64%/96.44%
# 101/200 | Cost: 10339.80 | Train/Valid Acc.: 97.61%/96.44%
# 102/200 | Cost: 10236.51 | Train/Valid Acc.: 97.65%/96.50%
# 103/200 | Cost: 10156.66 | Train/Valid Acc.: 97.67%/96.48%
# 104/200 | Cost: 10083.96 | Train/Valid Acc.: 97.72%/96.50%
# 105/200 | Cost: 10031.31 | Train/Valid Acc.: 97.72%/96.50%
# 106/200 | Cost: 9967.70 | Train/Valid Acc.: 97.73%/96.50%
# 107/200 | Cost: 9902.78 | Train/Valid Acc.: 97.76%/96.50%
# 108/200 | Cost: 9825.79 | Train/Valid Acc.: 97.78%/96.50%
# 109/200 | Cost: 9764.88 | Train/Valid Acc.: 97.80%/96.52%
# 110/200 | Cost: 9691.24 | Train/Valid Acc.: 97.83%/96.52%
# 111/200 | Cost: 9644.08 | Train/Valid Acc.: 97.84%/96.56%
# 112/200 | Cost: 9576.49 | Train/Valid Acc.: 97.84%/96.54%
# 113/200 | Cost: 9504.92 | Train/Valid Acc.: 97.89%/96.52%
# 114/200 | Cost: 9449.24 | Train/Valid Acc.: 97.89%/96.54%
# 115/200 | Cost: 9395.14 | Train/Valid Acc.: 97.92%/96.56%
# 116/200 | Cost: 9337.49 | Train/Valid Acc.: 97.92%/96.56%
# 117/200 | Cost: 9278.30 | Train/Valid Acc.: 97.92%/96.56%
# 118/200 | Cost: 9226.26 | Train/Valid Acc.: 97.98%/96.66%
# 119/200 | Cost: 9160.41 | Train/Valid Acc.: 97.98%/96.64%
# 120/200 | Cost: 9101.83 | Train/Valid Acc.: 98.02%/96.58%
# 121/200 | Cost: 9053.62 | Train/Valid Acc.: 98.01%/96.58%
# 122/200 | Cost: 8991.98 | Train/Valid Acc.: 98.03%/96.64%
# 123/200 | Cost: 8933.23 | Train/Valid Acc.: 98.04%/96.62%
# 124/200 | Cost: 8879.73 | Train/Valid Acc.: 98.07%/96.66%
# 125/200 | Cost: 8834.03 | Train/Valid Acc.: 98.10%/96.70%
# 126/200 | Cost: 8774.37 | Train/Valid Acc.: 98.11%/96.66%
# 127/200 | Cost: 8735.05 | Train/Valid Acc.: 98.13%/96.68%
# 128/200 | Cost: 8679.10 | Train/Valid Acc.: 98.14%/96.64%
# 129/200 | Cost: 8644.63 | Train/Valid Acc.: 98.14%/96.66%
# 130/200 | Cost: 8583.66 | Train/Valid Acc.: 98.16%/96.72%
# 131/200 | Cost: 8528.70 | Train/Valid Acc.: 98.18%/96.70%
# 132/200 | Cost: 8477.10 | Train/Valid Acc.: 98.18%/96.70%
# 133/200 | Cost: 8432.13 | Train/Valid Acc.: 98.19%/96.74%
# 134/200 | Cost: 8381.47 | Train/Valid Acc.: 98.21%/96.74%
# 135/200 | Cost: 8347.75 | Train/Valid Acc.: 98.25%/96.70%
# 136/200 | Cost: 8303.26 | Train/Valid Acc.: 98.25%/96.74%
# 137/200 | Cost: 8264.49 | Train/Valid Acc.: 98.25%/96.68%
# 138/200 | Cost: 8192.45 | Train/Valid Acc.: 98.29%/96.72%
# 139/200 | Cost: 8161.09 | Train/Valid Acc.: 98.29%/96.84%
# 140/200 | Cost: 8104.96 | Train/Valid Acc.: 98.29%/96.78%
# 141/200 | Cost: 8066.52 | Train/Valid Acc.: 98.31%/96.80%
# 142/200 | Cost: 8021.62 | Train/Valid Acc.: 98.33%/96.74%
# 143/200 | Cost: 7979.09 | Train/Valid Acc.: 98.33%/96.84%
# 144/200 | Cost: 7928.40 | Train/Valid Acc.: 98.36%/96.82%
# 145/200 | Cost: 7884.10 | Train/Valid Acc.: 98.37%/96.74%
# 146/200 | Cost: 7847.74 | Train/Valid Acc.: 98.37%/96.78%
# 147/200 | Cost: 7798.19 | Train/Valid Acc.: 98.39%/96.80%
# 148/200 | Cost: 7774.90 | Train/Valid Acc.: 98.41%/96.84%
# 149/200 | Cost: 7724.27 | Train/Valid Acc.: 98.41%/96.90%
# 150/200 | Cost: 7675.07 | Train/Valid Acc.: 98.41%/96.78%
# 151/200 | Cost: 7672.09 | Train/Valid Acc.: 98.41%/96.86%
# 152/200 | Cost: 7599.22 | Train/Valid Acc.: 98.46%/96.90%
# 153/200 | Cost: 7572.11 | Train/Valid Acc.: 98.44%/96.86%
# 154/200 | Cost: 7520.24 | Train/Valid Acc.: 98.44%/96.82%
# 155/200 | Cost: 7481.62 | Train/Valid Acc.: 98.45%/96.92%
# 156/200 | Cost: 7453.28 | Train/Valid Acc.: 98.48%/96.88%
# 157/200 | Cost: 7407.69 | Train/Valid Acc.: 98.48%/96.90%
# 158/200 | Cost: 7365.84 | Train/Valid Acc.: 98.51%/96.94%
# 159/200 | Cost: 7333.20 | Train/Valid Acc.: 98.50%/96.96%
# 160/200 | Cost: 7294.44 | Train/Valid Acc.: 98.51%/96.90%
# 161/200 | Cost: 7260.89 | Train/Valid Acc.: 98.53%/96.98%
# 162/200 | Cost: 7216.12 | Train/Valid Acc.: 98.53%/96.92%
# 163/200 | Cost: 7185.66 | Train/Valid Acc.: 98.54%/97.00%
# 164/200 | Cost: 7147.49 | Train/Valid Acc.: 98.55%/97.04%
# 165/200 | Cost: 7106.19 | Train/Valid Acc.: 98.57%/96.98%
# 166/200 | Cost: 7075.87 | Train/Valid Acc.: 98.56%/97.00%
# 167/200 | Cost: 7042.99 | Train/Valid Acc.: 98.57%/96.98%
# 168/200 | Cost: 7039.23 | Train/Valid Acc.: 98.57%/96.96%
# 169/200 | Cost: 6970.52 | Train/Valid Acc.: 98.59%/97.02%
# 170/200 | Cost: 6942.62 | Train/Valid Acc.: 98.59%/97.00%
# 171/200 | Cost: 6912.92 | Train/Valid Acc.: 98.60%/97.04%
# 172/200 | Cost: 6876.01 | Train/Valid Acc.: 98.61%/97.00%
# 173/200 | Cost: 6835.84 | Train/Valid Acc.: 98.63%/97.02%
# 174/200 | Cost: 6808.32 | Train/Valid Acc.: 98.64%/97.08%
# 175/200 | Cost: 6781.48 | Train/Valid Acc.: 98.64%/97.12%
# 176/200 | Cost: 6740.41 | Train/Valid Acc.: 98.65%/97.06%
# 177/200 | Cost: 6708.07 | Train/Valid Acc.: 98.65%/97.08%
# 178/200 | Cost: 6677.84 | Train/Valid Acc.: 98.67%/97.08%
# 179/200 | Cost: 6643.52 | Train/Valid Acc.: 98.67%/97.04%
# 180/200 | Cost: 6616.80 | Train/Valid Acc.: 98.69%/97.10%
# 181/200 | Cost: 6592.05 | Train/Valid Acc.: 98.69%/97.08%
# 182/200 | Cost: 6569.65 | Train/Valid Acc.: 98.68%/96.98%
# 183/200 | Cost: 6522.29 | Train/Valid Acc.: 98.70%/97.08%
# 184/200 | Cost: 6498.78 | Train/Valid Acc.: 98.72%/97.16%
# 185/200 | Cost: 6459.41 | Train/Valid Acc.: 98.71%/97.10%
# 186/200 | Cost: 6438.04 | Train/Valid Acc.: 98.73%/97.08%
# 187/200 | Cost: 6402.43 | Train/Valid Acc.: 98.74%/97.12%
# 188/200 | Cost: 6377.94 | Train/Valid Acc.: 98.74%/97.14%
# 189/200 | Cost: 6348.74 | Train/Valid Acc.: 98.76%/97.08%
# 190/200 | Cost: 6332.61 | Train/Valid Acc.: 98.77%/97.16%
# 191/200 | Cost: 6286.58 | Train/Valid Acc.: 98.77%/97.16%
# 192/200 | Cost: 6257.50 | Train/Valid Acc.: 98.77%/97.18%
# 193/200 | Cost: 6235.04 | Train/Valid Acc.: 98.77%/97.12%
# 194/200 | Cost: 6207.64 | Train/Valid Acc.: 98.80%/97.26%
# 195/200 | Cost: 6182.97 | Train/Valid Acc.: 98.81%/97.20%
# 196/200 | Cost: 6141.61 | Train/Valid Acc.: 98.81%/97.20%
# 197/200 | Cost: 6120.76 | Train/Valid Acc.: 98.81%/97.12%
# 198/200 | Cost: 6106.12 | Train/Valid Acc.: 98.82%/97.16%
# 199/200 | Cost: 6062.25 | Train/Valid Acc.: 98.83%/97.26%
# 200/200 | Cost: 6038.35 | Train/Valid Acc.: 98.83%/97.20%
# 001/200 | Cost: 83594.54 | Train/Valid Acc.: 81.58%/81.32%
# 002/200 | Cost: 59975.70 | Train/Valid Acc.: 85.95%/85.78%
# 003/200 | Cost: 50155.54 | Train/Valid Acc.: 88.10%/88.12%
# 004/200 | Cost: 44588.10 | Train/Valid Acc.: 89.08%/88.62%
# 005/200 | Cost: 41053.82 | Train/Valid Acc.: 89.78%/89.46%
# 006/200 | Cost: 38546.76 | Train/Valid Acc.: 90.22%/90.06%
# 007/200 | Cost: 36592.15 | Train/Valid Acc.: 90.57%/90.36%
# 008/200 | Cost: 35026.16 | Train/Valid Acc.: 90.89%/90.60%
# 009/200 | Cost: 33610.51 | Train/Valid Acc.: 91.27%/90.94%
# 010/200 | Cost: 32394.99 | Train/Valid Acc.: 91.56%/91.18%
# 011/200 | Cost: 31381.66 | Train/Valid Acc.: 91.78%/91.30%
# 012/200 | Cost: 30474.90 | Train/Valid Acc.: 92.10%/91.66%
# 013/200 | Cost: 29612.87 | Train/Valid Acc.: 92.26%/92.02%
# 014/200 | Cost: 28793.65 | Train/Valid Acc.: 92.51%/92.02%
# 015/200 | Cost: 28034.75 | Train/Valid Acc.: 92.70%/92.24%
# 016/200 | Cost: 27346.86 | Train/Valid Acc.: 92.89%/92.40%
# 017/200 | Cost: 26745.99 | Train/Valid Acc.: 93.03%/92.52%
# 018/200 | Cost: 26132.35 | Train/Valid Acc.: 93.21%/92.70%
# 019/200 | Cost: 25565.97 | Train/Valid Acc.: 93.33%/92.84%
# 020/200 | Cost: 25063.18 | Train/Valid Acc.: 93.44%/93.00%
# 021/200 | Cost: 24527.68 | Train/Valid Acc.: 93.63%/93.12%
# 022/200 | Cost: 24059.69 | Train/Valid Acc.: 93.72%/93.16%
# 023/200 | Cost: 23612.23 | Train/Valid Acc.: 93.87%/93.32%
# 024/200 | Cost: 23195.58 | Train/Valid Acc.: 93.97%/93.48%
# 025/200 | Cost: 22777.03 | Train/Valid Acc.: 94.10%/93.64%
# 026/200 | Cost: 22412.77 | Train/Valid Acc.: 94.12%/93.54%
# 027/200 | Cost: 21997.64 | Train/Valid Acc.: 94.28%/93.76%
# 028/200 | Cost: 21615.41 | Train/Valid Acc.: 94.39%/93.96%
# 029/200 | Cost: 21280.88 | Train/Valid Acc.: 94.48%/94.06%
# 030/200 | Cost: 20955.54 | Train/Valid Acc.: 94.59%/94.20%
# 031/200 | Cost: 20622.56 | Train/Valid Acc.: 94.69%/94.38%
# 032/200 | Cost: 20302.06 | Train/Valid Acc.: 94.77%/94.40%
# 033/200 | Cost: 20027.76 | Train/Valid Acc.: 94.83%/94.54%
# 034/200 | Cost: 19743.32 | Train/Valid Acc.: 94.91%/94.66%
# 035/200 | Cost: 19459.29 | Train/Valid Acc.: 94.99%/94.78%
# 036/200 | Cost: 19151.73 | Train/Valid Acc.: 95.08%/94.78%
# 037/200 | Cost: 18911.29 | Train/Valid Acc.: 95.17%/94.86%
# 038/200 | Cost: 18643.03 | Train/Valid Acc.: 95.20%/94.88%
# 039/200 | Cost: 18410.59 | Train/Valid Acc.: 95.25%/94.90%
# 040/200 | Cost: 18183.14 | Train/Valid Acc.: 95.31%/94.88%
# 041/200 | Cost: 17917.77 | Train/Valid Acc.: 95.41%/95.10%
# 042/200 | Cost: 17686.15 | Train/Valid Acc.: 95.49%/95.14%
# 043/200 | Cost: 17479.36 | Train/Valid Acc.: 95.53%/95.20%
# 044/200 | Cost: 17264.32 | Train/Valid Acc.: 95.63%/95.14%
# 045/200 | Cost: 17058.04 | Train/Valid Acc.: 95.67%/95.20%
# 046/200 | Cost: 16853.31 | Train/Valid Acc.: 95.69%/95.18%
# 047/200 | Cost: 16645.85 | Train/Valid Acc.: 95.81%/95.26%
# 048/200 | Cost: 16452.80 | Train/Valid Acc.: 95.86%/95.34%
# 049/200 | Cost: 16268.47 | Train/Valid Acc.: 95.89%/95.42%
# 050/200 | Cost: 16082.57 | Train/Valid Acc.: 95.97%/95.42%
# 051/200 | Cost: 15919.68 | Train/Valid Acc.: 96.00%/95.54%
# 052/200 | Cost: 15742.47 | Train/Valid Acc.: 96.07%/95.54%
# 053/200 | Cost: 15569.13 | Train/Valid Acc.: 96.14%/95.62%
# 054/200 | Cost: 15391.77 | Train/Valid Acc.: 96.14%/95.50%
# 055/200 | Cost: 15242.95 | Train/Valid Acc.: 96.18%/95.68%
# 056/200 | Cost: 15052.46 | Train/Valid Acc.: 96.25%/95.74%
# 057/200 | Cost: 14917.50 | Train/Valid Acc.: 96.31%/95.68%
# 058/200 | Cost: 14757.12 | Train/Valid Acc.: 96.35%/95.76%
# 059/200 | Cost: 14609.75 | Train/Valid Acc.: 96.41%/95.76%
# 060/200 | Cost: 14470.01 | Train/Valid Acc.: 96.44%/95.70%
# 061/200 | Cost: 14313.33 | Train/Valid Acc.: 96.48%/95.80%
# 062/200 | Cost: 14197.98 | Train/Valid Acc.: 96.53%/95.96%
# 063/200 | Cost: 14030.74 | Train/Valid Acc.: 96.55%/95.88%
# 064/200 | Cost: 13908.87 | Train/Valid Acc.: 96.60%/95.86%
# 065/200 | Cost: 13803.29 | Train/Valid Acc.: 96.62%/96.00%
# 066/200 | Cost: 13647.23 | Train/Valid Acc.: 96.68%/95.88%
# 067/200 | Cost: 13517.48 | Train/Valid Acc.: 96.74%/95.98%
# 068/200 | Cost: 13403.16 | Train/Valid Acc.: 96.77%/95.94%
# 069/200 | Cost: 13272.05 | Train/Valid Acc.: 96.79%/96.00%
# 070/200 | Cost: 13150.32 | Train/Valid Acc.: 96.81%/96.10%
# 071/200 | Cost: 13040.33 | Train/Valid Acc.: 96.87%/96.08%
# 072/200 | Cost: 12944.03 | Train/Valid Acc.: 96.90%/96.02%
# 073/200 | Cost: 12803.34 | Train/Valid Acc.: 96.93%/96.02%
# 074/200 | Cost: 12700.09 | Train/Valid Acc.: 96.97%/96.04%
# 075/200 | Cost: 12596.94 | Train/Valid Acc.: 96.99%/96.14%
# 076/200 | Cost: 12485.32 | Train/Valid Acc.: 97.05%/96.12%
# 077/200 | Cost: 12397.74 | Train/Valid Acc.: 97.03%/96.12%
# 078/200 | Cost: 12312.01 | Train/Valid Acc.: 97.10%/96.18%
# 079/200 | Cost: 12182.82 | Train/Valid Acc.: 97.14%/96.22%
# 080/200 | Cost: 12080.95 | Train/Valid Acc.: 97.15%/96.16%
# 081/200 | Cost: 11991.87 | Train/Valid Acc.: 97.19%/96.18%
# 082/200 | Cost: 11875.03 | Train/Valid Acc.: 97.21%/96.28%
# 083/200 | Cost: 11792.85 | Train/Valid Acc.: 97.25%/96.28%
# 084/200 | Cost: 11683.58 | Train/Valid Acc.: 97.27%/96.30%
# 085/200 | Cost: 11604.36 | Train/Valid Acc.: 97.30%/96.34%
# 086/200 | Cost: 11510.02 | Train/Valid Acc.: 97.32%/96.32%
# 087/200 | Cost: 11423.62 | Train/Valid Acc.: 97.34%/96.28%
# 088/200 | Cost: 11335.27 | Train/Valid Acc.: 97.37%/96.30%
# 089/200 | Cost: 11258.19 | Train/Valid Acc.: 97.39%/96.32%
# 090/200 | Cost: 11179.27 | Train/Valid Acc.: 97.39%/96.32%
# 091/200 | Cost: 11094.55 | Train/Valid Acc.: 97.42%/96.36%
# 092/200 | Cost: 11007.18 | Train/Valid Acc.: 97.47%/96.40%
# 093/200 | Cost: 10947.85 | Train/Valid Acc.: 97.46%/96.36%
# 094/200 | Cost: 10840.20 | Train/Valid Acc.: 97.51%/96.40%
# 095/200 | Cost: 10757.99 | Train/Valid Acc.: 97.53%/96.40%
# 096/200 | Cost: 10676.11 | Train/Valid Acc.: 97.54%/96.42%
# 097/200 | Cost: 10611.09 | Train/Valid Acc.: 97.58%/96.36%
# 098/200 | Cost: 10531.14 | Train/Valid Acc.: 97.59%/96.48%
# 099/200 | Cost: 10461.00 | Train/Valid Acc.: 97.59%/96.44%
# 100/200 | Cost: 10378.96 | Train/Valid Acc.: 97.64%/96.44%
# 101/200 | Cost: 10350.20 | Train/Valid Acc.: 97.61%/96.44%
# 102/200 | Cost: 10246.98 | Train/Valid Acc.: 97.65%/96.50%
# 103/200 | Cost: 10167.14 | Train/Valid Acc.: 97.67%/96.50%
# 104/200 | Cost: 10094.51 | Train/Valid Acc.: 97.71%/96.50%
# 105/200 | Cost: 10041.96 | Train/Valid Acc.: 97.71%/96.50%
# 106/200 | Cost: 9978.40 | Train/Valid Acc.: 97.73%/96.50%
# 107/200 | Cost: 9913.51 | Train/Valid Acc.: 97.76%/96.50%
# 108/200 | Cost: 9836.57 | Train/Valid Acc.: 97.78%/96.48%
# 109/200 | Cost: 9775.72 | Train/Valid Acc.: 97.79%/96.52%
# 110/200 | Cost: 9702.15 | Train/Valid Acc.: 97.83%/96.52%
# 111/200 | Cost: 9655.06 | Train/Valid Acc.: 97.84%/96.56%
# 112/200 | Cost: 9587.54 | Train/Valid Acc.: 97.84%/96.54%
# 113/200 | Cost: 9515.99 | Train/Valid Acc.: 97.88%/96.52%
# 114/200 | Cost: 9460.36 | Train/Valid Acc.: 97.89%/96.54%
# 115/200 | Cost: 9406.31 | Train/Valid Acc.: 97.92%/96.56%
# 116/200 | Cost: 9348.74 | Train/Valid Acc.: 97.92%/96.56%
# 117/200 | Cost: 9289.60 | Train/Valid Acc.: 97.93%/96.56%
# 118/200 | Cost: 9237.63 | Train/Valid Acc.: 97.98%/96.66%
# 119/200 | Cost: 9171.83 | Train/Valid Acc.: 97.98%/96.64%
# 120/200 | Cost: 9113.30 | Train/Valid Acc.: 98.02%/96.58%
# 121/200 | Cost: 9065.13 | Train/Valid Acc.: 98.01%/96.58%
# 122/200 | Cost: 9003.56 | Train/Valid Acc.: 98.03%/96.64%
# 123/200 | Cost: 8944.86 | Train/Valid Acc.: 98.04%/96.62%
# 124/200 | Cost: 8891.42 | Train/Valid Acc.: 98.07%/96.64%
# 125/200 | Cost: 8845.80 | Train/Valid Acc.: 98.09%/96.70%
# 126/200 | Cost: 8786.18 | Train/Valid Acc.: 98.11%/96.66%
# 127/200 | Cost: 8746.90 | Train/Valid Acc.: 98.13%/96.68%
# 128/200 | Cost: 8691.03 | Train/Valid Acc.: 98.13%/96.64%
# 129/200 | Cost: 8656.61 | Train/Valid Acc.: 98.14%/96.66%
# 130/200 | Cost: 8595.72 | Train/Valid Acc.: 98.16%/96.72%
# 131/200 | Cost: 8540.83 | Train/Valid Acc.: 98.18%/96.70%
# 132/200 | Cost: 8489.26 | Train/Valid Acc.: 98.18%/96.68%
# 133/200 | Cost: 8444.33 | Train/Valid Acc.: 98.19%/96.74%
# 134/200 | Cost: 8393.72 | Train/Valid Acc.: 98.21%/96.74%
# 135/200 | Cost: 8360.13 | Train/Valid Acc.: 98.25%/96.68%
# 136/200 | Cost: 8315.68 | Train/Valid Acc.: 98.25%/96.74%
# 137/200 | Cost: 8276.99 | Train/Valid Acc.: 98.25%/96.68%
# 138/200 | Cost: 8204.94 | Train/Valid Acc.: 98.28%/96.72%
# 139/200 | Cost: 8173.67 | Train/Valid Acc.: 98.30%/96.84%
# 140/200 | Cost: 8117.58 | Train/Valid Acc.: 98.29%/96.76%
# 141/200 | Cost: 8079.16 | Train/Valid Acc.: 98.31%/96.80%
# 142/200 | Cost: 8034.33 | Train/Valid Acc.: 98.33%/96.74%
# 143/200 | Cost: 7991.91 | Train/Valid Acc.: 98.33%/96.82%
# 144/200 | Cost: 7941.26 | Train/Valid Acc.: 98.35%/96.82%
# 145/200 | Cost: 7896.98 | Train/Valid Acc.: 98.36%/96.74%
# 146/200 | Cost: 7860.71 | Train/Valid Acc.: 98.37%/96.78%
# 147/200 | Cost: 7811.20 | Train/Valid Acc.: 98.38%/96.80%
# 148/200 | Cost: 7788.02 | Train/Valid Acc.: 98.41%/96.84%
# 149/200 | Cost: 7737.38 | Train/Valid Acc.: 98.41%/96.90%
# 150/200 | Cost: 7688.23 | Train/Valid Acc.: 98.40%/96.78%
# 151/200 | Cost: 7685.37 | Train/Valid Acc.: 98.40%/96.86%
# 152/200 | Cost: 7612.53 | Train/Valid Acc.: 98.46%/96.90%
# 153/200 | Cost: 7585.46 | Train/Valid Acc.: 98.44%/96.88%
# 154/200 | Cost: 7533.64 | Train/Valid Acc.: 98.44%/96.82%
# 155/200 | Cost: 7495.07 | Train/Valid Acc.: 98.44%/96.92%
# 156/200 | Cost: 7466.80 | Train/Valid Acc.: 98.47%/96.88%
# 157/200 | Cost: 7421.27 | Train/Valid Acc.: 98.48%/96.92%
# 158/200 | Cost: 7379.44 | Train/Valid Acc.: 98.51%/96.94%
# 159/200 | Cost: 7346.89 | Train/Valid Acc.: 98.50%/96.96%
# 160/200 | Cost: 7308.19 | Train/Valid Acc.: 98.51%/96.90%
# 161/200 | Cost: 7274.71 | Train/Valid Acc.: 98.53%/96.96%
# 162/200 | Cost: 7230.00 | Train/Valid Acc.: 98.53%/96.88%
# 163/200 | Cost: 7199.54 | Train/Valid Acc.: 98.54%/97.00%
# 164/200 | Cost: 7161.49 | Train/Valid Acc.: 98.55%/97.02%
# 165/200 | Cost: 7120.21 | Train/Valid Acc.: 98.57%/96.98%
# 166/200 | Cost: 7089.94 | Train/Valid Acc.: 98.56%/97.02%
# 167/200 | Cost: 7057.14 | Train/Valid Acc.: 98.57%/96.98%
# 168/200 | Cost: 7053.52 | Train/Valid Acc.: 98.57%/96.94%
# 169/200 | Cost: 6984.80 | Train/Valid Acc.: 98.59%/97.02%
# 170/200 | Cost: 6956.92 | Train/Valid Acc.: 98.59%/97.00%
# 171/200 | Cost: 6927.26 | Train/Valid Acc.: 98.59%/97.00%
# 172/200 | Cost: 6890.43 | Train/Valid Acc.: 98.61%/97.00%
# 173/200 | Cost: 6850.32 | Train/Valid Acc.: 98.63%/97.02%
# 174/200 | Cost: 6822.87 | Train/Valid Acc.: 98.64%/97.08%
# 175/200 | Cost: 6796.07 | Train/Valid Acc.: 98.64%/97.12%
# 176/200 | Cost: 6755.05 | Train/Valid Acc.: 98.65%/97.06%
# 177/200 | Cost: 6722.77 | Train/Valid Acc.: 98.65%/97.08%
# 178/200 | Cost: 6692.60 | Train/Valid Acc.: 98.66%/97.04%
# 179/200 | Cost: 6658.34 | Train/Valid Acc.: 98.67%/97.02%
# 180/200 | Cost: 6631.65 | Train/Valid Acc.: 98.69%/97.10%
# 181/200 | Cost: 6607.00 | Train/Valid Acc.: 98.69%/97.08%
# 182/200 | Cost: 6584.60 | Train/Valid Acc.: 98.68%/96.98%
# 183/200 | Cost: 6537.35 | Train/Valid Acc.: 98.69%/97.08%
# 184/200 | Cost: 6513.93 | Train/Valid Acc.: 98.72%/97.14%
# 185/200 | Cost: 6474.55 | Train/Valid Acc.: 98.71%/97.10%
# 186/200 | Cost: 6453.25 | Train/Valid Acc.: 98.73%/97.08%
# 187/200 | Cost: 6417.72 | Train/Valid Acc.: 98.74%/97.12%
# 188/200 | Cost: 6393.30 | Train/Valid Acc.: 98.74%/97.14%
# 189/200 | Cost: 6364.13 | Train/Valid Acc.: 98.76%/97.08%
# 190/200 | Cost: 6348.14 | Train/Valid Acc.: 98.76%/97.16%
# 191/200 | Cost: 6302.08 | Train/Valid Acc.: 98.76%/97.16%
# 192/200 | Cost: 6273.05 | Train/Valid Acc.: 98.77%/97.18%
# 193/200 | Cost: 6250.67 | Train/Valid Acc.: 98.77%/97.12%
# 194/200 | Cost: 6223.29 | Train/Valid Acc.: 98.80%/97.26%
# 195/200 | Cost: 6198.67 | Train/Valid Acc.: 98.81%/97.22%
# 196/200 | Cost: 6157.37 | Train/Valid Acc.: 98.81%/97.22%
# 197/200 | Cost: 6136.60 | Train/Valid Acc.: 98.81%/97.10%
# 198/200 | Cost: 6122.02 | Train/Valid Acc.: 98.82%/97.16%
# 199/200 | Cost: 6078.19 | Train/Valid Acc.: 98.83%/97.26%
# 200/200 | Cost: 6054.34 | Train/Valid Acc.: 98.83%/97.20%
# 001/200 | Cost: 83603.92 | Train/Valid Acc.: 81.58%/81.32%
# 002/200 | Cost: 59987.63 | Train/Valid Acc.: 85.95%/85.78%
# 003/200 | Cost: 50169.22 | Train/Valid Acc.: 88.10%/88.14%
# 004/200 | Cost: 44603.09 | Train/Valid Acc.: 89.07%/88.62%
# 005/200 | Cost: 41070.00 | Train/Valid Acc.: 89.77%/89.46%
# 006/200 | Cost: 38564.31 | Train/Valid Acc.: 90.21%/90.06%
# 007/200 | Cost: 36611.04 | Train/Valid Acc.: 90.57%/90.34%
# 008/200 | Cost: 35046.45 | Train/Valid Acc.: 90.90%/90.58%
# 009/200 | Cost: 33632.23 | Train/Valid Acc.: 91.28%/90.94%
# 010/200 | Cost: 32418.24 | Train/Valid Acc.: 91.55%/91.18%
# 011/200 | Cost: 31406.48 | Train/Valid Acc.: 91.78%/91.28%
# 012/200 | Cost: 30501.23 | Train/Valid Acc.: 92.09%/91.66%
# 013/200 | Cost: 29640.84 | Train/Valid Acc.: 92.26%/91.98%
# 014/200 | Cost: 28823.05 | Train/Valid Acc.: 92.51%/92.00%
# 015/200 | Cost: 28065.55 | Train/Valid Acc.: 92.69%/92.24%
# 016/200 | Cost: 27379.10 | Train/Valid Acc.: 92.88%/92.40%
# 017/200 | Cost: 26779.70 | Train/Valid Acc.: 93.03%/92.52%
# 018/200 | Cost: 26167.36 | Train/Valid Acc.: 93.20%/92.70%
# 019/200 | Cost: 25602.39 | Train/Valid Acc.: 93.33%/92.82%
# 020/200 | Cost: 25100.94 | Train/Valid Acc.: 93.43%/93.00%
# 021/200 | Cost: 24566.70 | Train/Valid Acc.: 93.62%/93.12%
# 022/200 | Cost: 24100.11 | Train/Valid Acc.: 93.71%/93.12%
# 023/200 | Cost: 23653.81 | Train/Valid Acc.: 93.87%/93.30%
# 024/200 | Cost: 23238.63 | Train/Valid Acc.: 93.97%/93.48%
# 025/200 | Cost: 22821.34 | Train/Valid Acc.: 94.09%/93.64%
# 026/200 | Cost: 22458.38 | Train/Valid Acc.: 94.11%/93.54%
# 027/200 | Cost: 22044.22 | Train/Valid Acc.: 94.27%/93.74%
# 028/200 | Cost: 21663.13 | Train/Valid Acc.: 94.39%/93.94%
# 029/200 | Cost: 21329.83 | Train/Valid Acc.: 94.47%/94.04%
# 030/200 | Cost: 21005.81 | Train/Valid Acc.: 94.59%/94.18%
# 031/200 | Cost: 20673.90 | Train/Valid Acc.: 94.69%/94.38%
# 032/200 | Cost: 20354.46 | Train/Valid Acc.: 94.75%/94.38%
# 033/200 | Cost: 20081.26 | Train/Valid Acc.: 94.82%/94.48%
# 034/200 | Cost: 19798.15 | Train/Valid Acc.: 94.90%/94.66%
# 035/200 | Cost: 19515.23 | Train/Valid Acc.: 94.98%/94.76%
# 036/200 | Cost: 19208.54 | Train/Valid Acc.: 95.07%/94.78%
# 037/200 | Cost: 18969.27 | Train/Valid Acc.: 95.16%/94.86%
# 038/200 | Cost: 18701.95 | Train/Valid Acc.: 95.19%/94.88%
# 039/200 | Cost: 18470.44 | Train/Valid Acc.: 95.23%/94.88%
# 040/200 | Cost: 18244.14 | Train/Valid Acc.: 95.30%/94.84%
# 041/200 | Cost: 17979.63 | Train/Valid Acc.: 95.40%/95.12%
# 042/200 | Cost: 17748.95 | Train/Valid Acc.: 95.49%/95.14%
# 043/200 | Cost: 17543.20 | Train/Valid Acc.: 95.52%/95.20%
# 044/200 | Cost: 17329.02 | Train/Valid Acc.: 95.62%/95.12%
# 045/200 | Cost: 17123.70 | Train/Valid Acc.: 95.63%/95.20%
# 046/200 | Cost: 16919.83 | Train/Valid Acc.: 95.66%/95.18%
# 047/200 | Cost: 16713.22 | Train/Valid Acc.: 95.80%/95.26%
# 048/200 | Cost: 16521.10 | Train/Valid Acc.: 95.85%/95.34%
# 049/200 | Cost: 16337.58 | Train/Valid Acc.: 95.88%/95.40%
# 050/200 | Cost: 16152.71 | Train/Valid Acc.: 95.95%/95.42%
# 051/200 | Cost: 15990.85 | Train/Valid Acc.: 95.99%/95.54%
# 052/200 | Cost: 15814.31 | Train/Valid Acc.: 96.06%/95.54%
# 053/200 | Cost: 15641.56 | Train/Valid Acc.: 96.12%/95.62%
# 054/200 | Cost: 15465.04 | Train/Valid Acc.: 96.12%/95.50%
# 055/200 | Cost: 15317.07 | Train/Valid Acc.: 96.17%/95.68%
# 056/200 | Cost: 15127.11 | Train/Valid Acc.: 96.24%/95.74%
# 057/200 | Cost: 14993.04 | Train/Valid Acc.: 96.30%/95.68%
# 058/200 | Cost: 14833.55 | Train/Valid Acc.: 96.33%/95.76%
# 059/200 | Cost: 14686.88 | Train/Valid Acc.: 96.39%/95.74%
# 060/200 | Cost: 14547.81 | Train/Valid Acc.: 96.43%/95.70%
# 061/200 | Cost: 14392.04 | Train/Valid Acc.: 96.46%/95.82%
# 062/200 | Cost: 14277.38 | Train/Valid Acc.: 96.51%/95.94%
# 063/200 | Cost: 14110.83 | Train/Valid Acc.: 96.53%/95.88%
# 064/200 | Cost: 13989.59 | Train/Valid Acc.: 96.58%/95.86%
# 065/200 | Cost: 13884.64 | Train/Valid Acc.: 96.60%/95.96%
# 066/200 | Cost: 13729.34 | Train/Valid Acc.: 96.66%/95.88%
# 067/200 | Cost: 13600.38 | Train/Valid Acc.: 96.73%/95.98%
# 068/200 | Cost: 13487.01 | Train/Valid Acc.: 96.75%/95.96%
# 069/200 | Cost: 13356.26 | Train/Valid Acc.: 96.77%/96.00%
# 070/200 | Cost: 13235.08 | Train/Valid Acc.: 96.78%/96.10%
# 071/200 | Cost: 13125.72 | Train/Valid Acc.: 96.85%/96.06%
# 072/200 | Cost: 13030.63 | Train/Valid Acc.: 96.88%/96.00%
# 073/200 | Cost: 12890.42 | Train/Valid Acc.: 96.91%/96.02%
# 074/200 | Cost: 12787.91 | Train/Valid Acc.: 96.95%/96.04%
# 075/200 | Cost: 12685.29 | Train/Valid Acc.: 96.97%/96.16%
# 076/200 | Cost: 12574.37 | Train/Valid Acc.: 97.03%/96.10%
# 077/200 | Cost: 12487.45 | Train/Valid Acc.: 97.01%/96.08%
# 078/200 | Cost: 12402.61 | Train/Valid Acc.: 97.07%/96.16%
# 079/200 | Cost: 12273.73 | Train/Valid Acc.: 97.12%/96.20%
# 080/200 | Cost: 12172.73 | Train/Valid Acc.: 97.13%/96.18%
# 081/200 | Cost: 12084.66 | Train/Valid Acc.: 97.17%/96.12%
# 082/200 | Cost: 11967.85 | Train/Valid Acc.: 97.19%/96.24%
# 083/200 | Cost: 11886.53 | Train/Valid Acc.: 97.23%/96.22%
# 084/200 | Cost: 11777.67 | Train/Valid Acc.: 97.23%/96.28%
# 085/200 | Cost: 11699.22 | Train/Valid Acc.: 97.27%/96.34%
# 086/200 | Cost: 11605.30 | Train/Valid Acc.: 97.31%/96.34%
# 087/200 | Cost: 11519.56 | Train/Valid Acc.: 97.29%/96.22%
# 088/200 | Cost: 11431.93 | Train/Valid Acc.: 97.34%/96.28%
# 089/200 | Cost: 11355.28 | Train/Valid Acc.: 97.37%/96.32%
# 090/200 | Cost: 11277.04 | Train/Valid Acc.: 97.37%/96.32%
# 091/200 | Cost: 11192.87 | Train/Valid Acc.: 97.41%/96.32%
# 092/200 | Cost: 11106.38 | Train/Valid Acc.: 97.44%/96.38%
# 093/200 | Cost: 11047.55 | Train/Valid Acc.: 97.43%/96.40%
# 094/200 | Cost: 10940.57 | Train/Valid Acc.: 97.50%/96.42%
# 095/200 | Cost: 10858.88 | Train/Valid Acc.: 97.50%/96.40%
# 096/200 | Cost: 10777.55 | Train/Valid Acc.: 97.51%/96.40%
# 097/200 | Cost: 10713.34 | Train/Valid Acc.: 97.56%/96.36%
# 098/200 | Cost: 10633.87 | Train/Valid Acc.: 97.57%/96.46%
# 099/200 | Cost: 10564.47 | Train/Valid Acc.: 97.57%/96.46%
# 100/200 | Cost: 10482.80 | Train/Valid Acc.: 97.61%/96.40%
# 101/200 | Cost: 10454.82 | Train/Valid Acc.: 97.60%/96.46%
# 102/200 | Cost: 10352.33 | Train/Valid Acc.: 97.63%/96.46%
# 103/200 | Cost: 10272.54 | Train/Valid Acc.: 97.65%/96.48%
# 104/200 | Cost: 10200.74 | Train/Valid Acc.: 97.69%/96.50%
# 105/200 | Cost: 10149.16 | Train/Valid Acc.: 97.68%/96.52%
# 106/200 | Cost: 10086.12 | Train/Valid Acc.: 97.70%/96.48%
# 107/200 | Cost: 10021.53 | Train/Valid Acc.: 97.74%/96.52%
# 108/200 | Cost: 9945.12 | Train/Valid Acc.: 97.76%/96.48%
# 109/200 | Cost: 9884.93 | Train/Valid Acc.: 97.77%/96.50%
# 110/200 | Cost: 9811.98 | Train/Valid Acc.: 97.81%/96.52%
# 111/200 | Cost: 9765.53 | Train/Valid Acc.: 97.82%/96.56%
# 112/200 | Cost: 9698.80 | Train/Valid Acc.: 97.82%/96.48%
# 113/200 | Cost: 9627.45 | Train/Valid Acc.: 97.86%/96.54%
# 114/200 | Cost: 9572.37 | Train/Valid Acc.: 97.87%/96.54%
# 115/200 | Cost: 9518.85 | Train/Valid Acc.: 97.90%/96.56%
# 116/200 | Cost: 9462.11 | Train/Valid Acc.: 97.89%/96.58%
# 117/200 | Cost: 9403.40 | Train/Valid Acc.: 97.89%/96.58%
# 118/200 | Cost: 9352.09 | Train/Valid Acc.: 97.95%/96.66%
# 119/200 | Cost: 9286.86 | Train/Valid Acc.: 97.96%/96.62%
# 120/200 | Cost: 9228.80 | Train/Valid Acc.: 97.99%/96.58%
# 121/200 | Cost: 9181.08 | Train/Valid Acc.: 97.99%/96.58%
# 122/200 | Cost: 9120.28 | Train/Valid Acc.: 98.00%/96.60%
# 123/200 | Cost: 9061.94 | Train/Valid Acc.: 98.01%/96.60%
# 124/200 | Cost: 9009.17 | Train/Valid Acc.: 98.04%/96.64%
# 125/200 | Cost: 8964.35 | Train/Valid Acc.: 98.07%/96.72%
# 126/200 | Cost: 8905.12 | Train/Valid Acc.: 98.08%/96.66%
# 127/200 | Cost: 8866.27 | Train/Valid Acc.: 98.10%/96.66%
# 128/200 | Cost: 8811.18 | Train/Valid Acc.: 98.11%/96.66%
# 129/200 | Cost: 8777.35 | Train/Valid Acc.: 98.12%/96.68%
# 130/200 | Cost: 8717.15 | Train/Valid Acc.: 98.13%/96.72%
# 131/200 | Cost: 8663.05 | Train/Valid Acc.: 98.16%/96.66%
# 132/200 | Cost: 8611.78 | Train/Valid Acc.: 98.15%/96.68%
# 133/200 | Cost: 8567.25 | Train/Valid Acc.: 98.17%/96.70%
# 134/200 | Cost: 8517.16 | Train/Valid Acc.: 98.19%/96.72%
# 135/200 | Cost: 8484.88 | Train/Valid Acc.: 98.23%/96.66%
# 136/200 | Cost: 8440.77 | Train/Valid Acc.: 98.23%/96.74%
# 137/200 | Cost: 8402.91 | Train/Valid Acc.: 98.22%/96.72%
# 138/200 | Cost: 8330.85 | Train/Valid Acc.: 98.25%/96.72%
# 139/200 | Cost: 8300.45 | Train/Valid Acc.: 98.28%/96.82%
# 140/200 | Cost: 8244.79 | Train/Valid Acc.: 98.27%/96.76%
# 141/200 | Cost: 8206.60 | Train/Valid Acc.: 98.29%/96.72%
# 142/200 | Cost: 8162.46 | Train/Valid Acc.: 98.30%/96.74%
# 143/200 | Cost: 8121.10 | Train/Valid Acc.: 98.31%/96.78%
# 144/200 | Cost: 8070.91 | Train/Valid Acc.: 98.32%/96.80%
# 145/200 | Cost: 8026.86 | Train/Valid Acc.: 98.34%/96.74%
# 146/200 | Cost: 7991.35 | Train/Valid Acc.: 98.35%/96.78%
# 147/200 | Cost: 7942.29 | Train/Valid Acc.: 98.35%/96.78%
# 148/200 | Cost: 7920.22 | Train/Valid Acc.: 98.39%/96.78%
# 149/200 | Cost: 7869.55 | Train/Valid Acc.: 98.37%/96.86%
# 150/200 | Cost: 7820.91 | Train/Valid Acc.: 98.38%/96.76%
# 151/200 | Cost: 7819.26 | Train/Valid Acc.: 98.38%/96.80%
# 152/200 | Cost: 7746.67 | Train/Valid Acc.: 98.43%/96.84%
# 153/200 | Cost: 7720.05 | Train/Valid Acc.: 98.41%/96.86%
# 154/200 | Cost: 7668.70 | Train/Valid Acc.: 98.42%/96.82%
# 155/200 | Cost: 7630.72 | Train/Valid Acc.: 98.41%/96.86%
# 156/200 | Cost: 7603.15 | Train/Valid Acc.: 98.45%/96.82%
# 157/200 | Cost: 7558.25 | Train/Valid Acc.: 98.44%/96.86%
# 158/200 | Cost: 7516.54 | Train/Valid Acc.: 98.49%/96.92%
# 159/200 | Cost: 7484.93 | Train/Valid Acc.: 98.47%/96.90%
# 160/200 | Cost: 7446.79 | Train/Valid Acc.: 98.48%/96.86%
# 161/200 | Cost: 7414.04 | Train/Valid Acc.: 98.50%/96.90%
# 162/200 | Cost: 7369.93 | Train/Valid Acc.: 98.51%/96.86%
# 163/200 | Cost: 7339.51 | Train/Valid Acc.: 98.51%/96.96%
# 164/200 | Cost: 7302.66 | Train/Valid Acc.: 98.53%/96.96%
# 165/200 | Cost: 7261.53 | Train/Valid Acc.: 98.55%/97.00%
# 166/200 | Cost: 7231.81 | Train/Valid Acc.: 98.55%/96.98%
# 167/200 | Cost: 7199.88 | Train/Valid Acc.: 98.55%/96.92%
# 168/200 | Cost: 7197.59 | Train/Valid Acc.: 98.55%/96.88%
# 169/200 | Cost: 7128.78 | Train/Valid Acc.: 98.58%/96.98%
# 170/200 | Cost: 7101.13 | Train/Valid Acc.: 98.57%/96.98%
# 171/200 | Cost: 7071.88 | Train/Valid Acc.: 98.59%/96.98%
# 172/200 | Cost: 7035.91 | Train/Valid Acc.: 98.60%/96.98%
# 173/200 | Cost: 6996.33 | Train/Valid Acc.: 98.61%/97.00%
# 174/200 | Cost: 6969.68 | Train/Valid Acc.: 98.61%/97.06%
# 175/200 | Cost: 6943.17 | Train/Valid Acc.: 98.61%/97.04%
# 176/200 | Cost: 6902.72 | Train/Valid Acc.: 98.62%/97.00%
# 177/200 | Cost: 6871.02 | Train/Valid Acc.: 98.62%/97.04%
# 178/200 | Cost: 6841.56 | Train/Valid Acc.: 98.64%/97.04%
# 179/200 | Cost: 6807.85 | Train/Valid Acc.: 98.65%/97.02%
# 180/200 | Cost: 6781.48 | Train/Valid Acc.: 98.65%/97.06%
# 181/200 | Cost: 6757.84 | Train/Valid Acc.: 98.65%/97.04%
# 182/200 | Cost: 6735.47 | Train/Valid Acc.: 98.65%/97.00%
# 183/200 | Cost: 6689.31 | Train/Valid Acc.: 98.67%/97.08%
# 184/200 | Cost: 6666.84 | Train/Valid Acc.: 98.68%/97.12%
# 185/200 | Cost: 6627.39 | Train/Valid Acc.: 98.69%/97.10%
# 186/200 | Cost: 6606.76 | Train/Valid Acc.: 98.70%/97.10%
# 187/200 | Cost: 6571.96 | Train/Valid Acc.: 98.70%/97.12%
# 188/200 | Cost: 6548.25 | Train/Valid Acc.: 98.71%/97.10%
# 189/200 | Cost: 6519.41 | Train/Valid Acc.: 98.73%/97.08%
# 190/200 | Cost: 6504.92 | Train/Valid Acc.: 98.74%/97.16%
# 191/200 | Cost: 6458.63 | Train/Valid Acc.: 98.73%/97.12%
# 192/200 | Cost: 6429.97 | Train/Valid Acc.: 98.75%/97.12%
# 193/200 | Cost: 6408.41 | Train/Valid Acc.: 98.75%/97.12%
# 194/200 | Cost: 6381.21 | Train/Valid Acc.: 98.77%/97.20%
# 195/200 | Cost: 6357.14 | Train/Valid Acc.: 98.79%/97.16%
# 196/200 | Cost: 6316.50 | Train/Valid Acc.: 98.78%/97.14%
# 197/200 | Cost: 6296.56 | Train/Valid Acc.: 98.77%/97.14%
# 198/200 | Cost: 6282.48 | Train/Valid Acc.: 98.80%/97.20%
# 199/200 | Cost: 6239.07 | Train/Valid Acc.: 98.80%/97.24%
# 200/200 | Cost: 6215.79 | Train/Valid Acc.: 98.80%/97.18%
# 001/200 | Cost: 83697.77 | Train/Valid Acc.: 81.57%/81.32%
# 002/200 | Cost: 60107.00 | Train/Valid Acc.: 85.93%/85.78%
# 003/200 | Cost: 50306.22 | Train/Valid Acc.: 88.09%/88.14%
# 004/200 | Cost: 44753.26 | Train/Valid Acc.: 89.06%/88.64%
# 005/200 | Cost: 41232.30 | Train/Valid Acc.: 89.77%/89.46%
# 006/200 | Cost: 38740.46 | Train/Valid Acc.: 90.20%/90.04%
# ...
# 138/200 | Cost: 56012.05 | Train/Valid Acc.: 88.73%/88.64%
# 139/200 | Cost: 55947.74 | Train/Valid Acc.: 88.78%/88.62%
# 140/200 | Cost: 55943.12 | Train/Valid Acc.: 88.76%/88.74%
# 141/200 | Cost: 55974.40 | Train/Valid Acc.: 88.88%/88.86%
# 142/200 | Cost: 55957.26 | Train/Valid Acc.: 88.81%/88.68%
# 143/200 | Cost: 55922.37 | Train/Valid Acc.: 88.84%/88.64%
# 144/200 | Cost: 56007.21 | Train/Valid Acc.: 88.78%/88.72%
# 145/200 | Cost: 55959.01 | Train/Valid Acc.: 88.76%/88.54%
# 146/200 | Cost: 56108.02 | Train/Valid Acc.: 88.74%/88.58%
# 147/200 | Cost: 55949.08 | Train/Valid Acc.: 88.80%/88.72%
# 148/200 | Cost: 56058.78 | Train/Valid Acc.: 88.79%/88.76%
# 149/200 | Cost: 56023.85 | Train/Valid Acc.: 88.66%/88.50%
# 150/200 | Cost: 55974.49 | Train/Valid Acc.: 88.78%/88.76%
# 151/200 | Cost: 55976.28 | Train/Valid Acc.: 88.84%/88.76%
# 152/200 | Cost: 55984.24 | Train/Valid Acc.: 88.76%/88.66%
# 153/200 | Cost: 55986.17 | Train/Valid Acc.: 88.57%/88.46%
# 154/200 | Cost: 55957.97 | Train/Valid Acc.: 88.82%/88.84%
# 155/200 | Cost: 55953.68 | Train/Valid Acc.: 88.76%/88.74%
# 156/200 | Cost: 55951.23 | Train/Valid Acc.: 88.70%/88.82%
# 157/200 | Cost: 56010.70 | Train/Valid Acc.: 88.81%/88.68%
# 158/200 | Cost: 55970.29 | Train/Valid Acc.: 88.79%/88.84%
# 159/200 | Cost: 55958.78 | Train/Valid Acc.: 88.81%/88.74%
# 160/200 | Cost: 56024.21 | Train/Valid Acc.: 88.70%/88.78%
# 161/200 | Cost: 55940.14 | Train/Valid Acc.: 88.81%/88.84%
# 162/200 | Cost: 56023.83 | Train/Valid Acc.: 88.86%/88.78%
# 163/200 | Cost: 55949.11 | Train/Valid Acc.: 88.88%/88.82%
# 164/200 | Cost: 56015.59 | Train/Valid Acc.: 88.73%/88.58%
# 165/200 | Cost: 55927.49 | Train/Valid Acc.: 88.81%/88.60%
# 166/200 | Cost: 55925.39 | Train/Valid Acc.: 88.73%/88.72%
# 167/200 | Cost: 56027.98 | Train/Valid Acc.: 88.78%/88.80%
# 168/200 | Cost: 56010.95 | Train/Valid Acc.: 88.98%/88.84%
# 169/200 | Cost: 55921.73 | Train/Valid Acc.: 88.68%/88.70%
# 170/200 | Cost: 55932.29 | Train/Valid Acc.: 88.83%/88.74%
# 171/200 | Cost: 55950.17 | Train/Valid Acc.: 88.80%/88.88%
# 172/200 | Cost: 55891.02 | Train/Valid Acc.: 88.67%/88.68%
# 173/200 | Cost: 55959.41 | Train/Valid Acc.: 88.84%/88.84%
# 174/200 | Cost: 55988.37 | Train/Valid Acc.: 88.55%/88.42%
# 175/200 | Cost: 55923.49 | Train/Valid Acc.: 88.70%/88.68%
# 176/200 | Cost: 55876.72 | Train/Valid Acc.: 88.73%/88.68%
# 177/200 | Cost: 55940.72 | Train/Valid Acc.: 88.88%/88.80%
# 178/200 | Cost: 55939.65 | Train/Valid Acc.: 88.75%/88.64%
# 179/200 | Cost: 56014.75 | Train/Valid Acc.: 88.73%/88.64%
# 180/200 | Cost: 55923.45 | Train/Valid Acc.: 88.75%/88.70%
# 181/200 | Cost: 55915.73 | Train/Valid Acc.: 88.84%/88.82%
# 182/200 | Cost: 55863.10 | Train/Valid Acc.: 88.84%/88.68%
# 183/200 | Cost: 55961.77 | Train/Valid Acc.: 88.82%/88.64%
# 184/200 | Cost: 55982.15 | Train/Valid Acc.: 88.72%/88.46%
# 185/200 | Cost: 55902.63 | Train/Valid Acc.: 88.73%/88.68%
# 186/200 | Cost: 55961.58 | Train/Valid Acc.: 88.97%/88.88%
# 187/200 | Cost: 55866.21 | Train/Valid Acc.: 88.93%/88.76%
# 188/200 | Cost: 55883.76 | Train/Valid Acc.: 88.80%/88.76%
# 189/200 | Cost: 55945.30 | Train/Valid Acc.: 88.86%/88.92%
# 190/200 | Cost: 55997.42 | Train/Valid Acc.: 88.83%/88.78%
# 191/200 | Cost: 56013.48 | Train/Valid Acc.: 89.01%/88.72%
# 192/200 | Cost: 55884.57 | Train/Valid Acc.: 88.86%/88.76%
# 193/200 | Cost: 55912.14 | Train/Valid Acc.: 88.83%/88.74%
# 194/200 | Cost: 55851.90 | Train/Valid Acc.: 88.77%/88.68%
# 195/200 | Cost: 55861.34 | Train/Valid Acc.: 88.73%/88.72%
# 196/200 | Cost: 55922.06 | Train/Valid Acc.: 88.82%/88.68%
# 197/200 | Cost: 55935.52 | Train/Valid Acc.: 88.58%/88.58%
# 198/200 | Cost: 55984.99 | Train/Valid Acc.: 88.85%/88.82%
# 199/200 | Cost: 55915.96 | Train/Valid Acc.: 88.73%/88.60%
# 200/200 | Cost: 55979.49 | Train/Valid Acc.: 88.56%/88.56%
# 001/200 | Cost: 165933.35 | Train/Valid Acc.: 41.32%/40.42%
# 002/200 | Cost: 164496.35 | Train/Valid Acc.: 44.99%/45.12%
# 003/200 | Cost: 163752.87 | Train/Valid Acc.: 44.40%/44.00%
# 004/200 | Cost: 163425.32 | Train/Valid Acc.: 38.30%/37.98%
# 005/200 | Cost: 163214.60 | Train/Valid Acc.: 39.12%/39.24%
# 006/200 | Cost: 163351.69 | Train/Valid Acc.: 34.03%/34.50%
# 007/200 | Cost: 162920.79 | Train/Valid Acc.: 35.05%/34.82%
# 008/200 | Cost: 162795.56 | Train/Valid Acc.: 33.83%/33.60%
# 009/200 | Cost: 162811.79 | Train/Valid Acc.: 34.38%/34.24%
# 010/200 | Cost: 162658.90 | Train/Valid Acc.: 39.59%/39.50%
# 011/200 | Cost: 162634.67 | Train/Valid Acc.: 38.72%/39.02%
# 012/200 | Cost: 162533.83 | Train/Valid Acc.: 39.42%/39.14%
# 013/200 | Cost: 162790.10 | Train/Valid Acc.: 39.31%/38.94%
# 014/200 | Cost: 162574.56 | Train/Valid Acc.: 31.05%/31.40%
# 015/200 | Cost: 162582.07 | Train/Valid Acc.: 35.83%/35.64%
# 016/200 | Cost: 162554.23 | Train/Valid Acc.: 40.78%/40.34%
# 017/200 | Cost: 162281.54 | Train/Valid Acc.: 41.00%/41.36%
# 018/200 | Cost: 162299.94 | Train/Valid Acc.: 37.91%/38.12%
# 019/200 | Cost: 162348.68 | Train/Valid Acc.: 32.77%/32.66%
# 020/200 | Cost: 162110.06 | Train/Valid Acc.: 36.52%/37.38%
# 021/200 | Cost: 162230.72 | Train/Valid Acc.: 39.26%/39.28%
# 022/200 | Cost: 162211.77 | Train/Valid Acc.: 36.74%/36.52%
# 023/200 | Cost: 162309.48 | Train/Valid Acc.: 44.51%/44.06%
# 024/200 | Cost: 162224.57 | Train/Valid Acc.: 34.09%/33.60%
# 025/200 | Cost: 162250.84 | Train/Valid Acc.: 37.05%/36.42%
# 026/200 | Cost: 162022.35 | Train/Valid Acc.: 35.73%/35.42%
# 027/200 | Cost: 162156.65 | Train/Valid Acc.: 38.01%/37.68%
# 028/200 | Cost: 161897.65 | Train/Valid Acc.: 36.16%/36.34%
# 029/200 | Cost: 162216.27 | Train/Valid Acc.: 42.98%/42.84%
# 030/200 | Cost: 162172.97 | Train/Valid Acc.: 35.97%/36.14%
# 031/200 | Cost: 162257.52 | Train/Valid Acc.: 38.64%/38.26%
# 032/200 | Cost: 162050.49 | Train/Valid Acc.: 39.59%/39.58%
# 033/200 | Cost: 161917.10 | Train/Valid Acc.: 37.09%/37.18%
# 034/200 | Cost: 161971.76 | Train/Valid Acc.: 37.07%/36.42%
# 035/200 | Cost: 161917.56 | Train/Valid Acc.: 41.69%/42.22%
# 036/200 | Cost: 161978.99 | Train/Valid Acc.: 38.84%/39.10%
# 037/200 | Cost: 161957.03 | Train/Valid Acc.: 36.13%/36.08%
# 038/200 | Cost: 161770.42 | Train/Valid Acc.: 33.12%/33.02%
# 039/200 | Cost: 161903.92 | Train/Valid Acc.: 38.91%/37.84%
# 040/200 | Cost: 161911.92 | Train/Valid Acc.: 30.30%/29.08%
# 041/200 | Cost: 161876.10 | Train/Valid Acc.: 36.84%/35.98%
# 042/200 | Cost: 161948.18 | Train/Valid Acc.: 42.10%/41.42%
# 043/200 | Cost: 161983.93 | Train/Valid Acc.: 38.84%/38.96%
# 044/200 | Cost: 161836.44 | Train/Valid Acc.: 37.25%/37.40%
# 045/200 | Cost: 162097.34 | Train/Valid Acc.: 40.23%/39.72%
# 046/200 | Cost: 162063.68 | Train/Valid Acc.: 37.92%/37.60%
# 047/200 | Cost: 161793.09 | Train/Valid Acc.: 39.59%/39.44%
# 048/200 | Cost: 161988.24 | Train/Valid Acc.: 42.82%/42.78%
# 049/200 | Cost: 161888.07 | Train/Valid Acc.: 41.29%/41.86%
# 050/200 | Cost: 161966.77 | Train/Valid Acc.: 38.94%/38.58%
# 051/200 | Cost: 162044.80 | Train/Valid Acc.: 41.16%/40.56%
# 052/200 | Cost: 161899.11 | Train/Valid Acc.: 39.11%/39.76%
# 053/200 | Cost: 161870.20 | Train/Valid Acc.: 40.40%/39.52%
# 054/200 | Cost: 161887.87 | Train/Valid Acc.: 37.07%/37.48%
# 055/200 | Cost: 161814.10 | Train/Valid Acc.: 37.18%/36.62%
# 056/200 | Cost: 161749.68 | Train/Valid Acc.: 33.57%/33.64%
# 057/200 | Cost: 161681.42 | Train/Valid Acc.: 36.54%/36.96%
# 058/200 | Cost: 161667.95 | Train/Valid Acc.: 36.72%/37.10%
# 059/200 | Cost: 161747.13 | Train/Valid Acc.: 36.41%/35.94%
# 060/200 | Cost: 161657.19 | Train/Valid Acc.: 40.00%/40.22%
# 061/200 | Cost: 161966.74 | Train/Valid Acc.: 40.46%/40.28%
# 062/200 | Cost: 161656.58 | Train/Valid Acc.: 34.25%/33.92%
# 063/200 | Cost: 161978.93 | Train/Valid Acc.: 32.01%/31.64%
# 064/200 | Cost: 161787.75 | Train/Valid Acc.: 35.49%/35.84%
# 065/200 | Cost: 161824.00 | Train/Valid Acc.: 38.02%/38.12%
# 066/200 | Cost: 161726.35 | Train/Valid Acc.: 36.51%/35.64%
# 067/200 | Cost: 161761.80 | Train/Valid Acc.: 34.28%/34.62%
# 068/200 | Cost: 161752.56 | Train/Valid Acc.: 41.36%/41.60%
# 069/200 | Cost: 161915.83 | Train/Valid Acc.: 37.28%/37.04%
# 070/200 | Cost: 161877.12 | Train/Valid Acc.: 33.01%/33.14%
# 071/200 | Cost: 161767.77 | Train/Valid Acc.: 34.71%/35.04%
# 072/200 | Cost: 161669.79 | Train/Valid Acc.: 33.05%/32.96%
# 073/200 | Cost: 161839.44 | Train/Valid Acc.: 33.26%/32.70%
# 074/200 | Cost: 161918.56 | Train/Valid Acc.: 43.45%/43.42%
# 075/200 | Cost: 161706.79 | Train/Valid Acc.: 39.71%/38.96%
# 076/200 | Cost: 161711.49 | Train/Valid Acc.: 30.55%/30.88%
# 077/200 | Cost: 161820.21 | Train/Valid Acc.: 39.93%/40.16%
# 078/200 | Cost: 161768.53 | Train/Valid Acc.: 41.09%/41.60%
# 079/200 | Cost: 161615.81 | Train/Valid Acc.: 39.03%/39.26%
# 080/200 | Cost: 161690.88 | Train/Valid Acc.: 37.15%/37.54%
# 081/200 | Cost: 161764.10 | Train/Valid Acc.: 45.26%/45.24%
# 082/200 | Cost: 161614.08 | Train/Valid Acc.: 36.64%/36.76%
# 083/200 | Cost: 161632.10 | Train/Valid Acc.: 34.92%/34.88%
# 084/200 | Cost: 162104.01 | Train/Valid Acc.: 40.13%/39.94%
# 085/200 | Cost: 161634.20 | Train/Valid Acc.: 31.41%/31.46%
# 086/200 | Cost: 161788.12 | Train/Valid Acc.: 39.33%/39.28%
# 087/200 | Cost: 161636.17 | Train/Valid Acc.: 32.18%/32.48%
# 088/200 | Cost: 161744.54 | Train/Valid Acc.: 39.73%/39.96%
# 089/200 | Cost: 161550.22 | Train/Valid Acc.: 32.57%/32.20%
# 090/200 | Cost: 161603.22 | Train/Valid Acc.: 33.98%/34.16%
# 091/200 | Cost: 161835.48 | Train/Valid Acc.: 42.77%/42.46%
# 092/200 | Cost: 162155.96 | Train/Valid Acc.: 35.58%/35.28%
# 093/200 | Cost: 161738.40 | Train/Valid Acc.: 39.37%/39.48%
# 094/200 | Cost: 161836.03 | Train/Valid Acc.: 36.77%/36.50%
# 095/200 | Cost: 161638.12 | Train/Valid Acc.: 35.03%/35.02%
# 096/200 | Cost: 161678.33 | Train/Valid Acc.: 42.85%/42.74%
# 097/200 | Cost: 161811.42 | Train/Valid Acc.: 40.07%/39.64%
# 098/200 | Cost: 161838.80 | Train/Valid Acc.: 37.91%/37.70%
# 099/200 | Cost: 161799.77 | Train/Valid Acc.: 39.02%/38.96%
# 100/200 | Cost: 161872.45 | Train/Valid Acc.: 43.85%/43.90%
# 101/200 | Cost: 161695.37 | Train/Valid Acc.: 33.38%/33.72%
# 102/200 | Cost: 161729.88 | Train/Valid Acc.: 34.07%/34.26%
# 103/200 | Cost: 161735.90 | Train/Valid Acc.: 35.97%/34.82%
# 104/200 | Cost: 161880.89 | Train/Valid Acc.: 41.04%/40.80%
# 105/200 | Cost: 161743.10 | Train/Valid Acc.: 36.82%/37.06%
# 106/200 | Cost: 161772.97 | Train/Valid Acc.: 38.46%/38.54%
# 107/200 | Cost: 161814.33 | Train/Valid Acc.: 40.30%/39.80%
# 108/200 | Cost: 161574.53 | Train/Valid Acc.: 37.88%/38.58%
# 109/200 | Cost: 161713.25 | Train/Valid Acc.: 34.07%/34.10%
# 110/200 | Cost: 161733.57 | Train/Valid Acc.: 31.63%/31.46%
# 111/200 | Cost: 161762.01 | Train/Valid Acc.: 41.77%/41.40%
# 112/200 | Cost: 161700.13 | Train/Valid Acc.: 37.93%/38.32%
# 113/200 | Cost: 161774.33 | Train/Valid Acc.: 41.91%/41.82%
# 114/200 | Cost: 161676.21 | Train/Valid Acc.: 39.59%/39.80%
# 115/200 | Cost: 161911.77 | Train/Valid Acc.: 42.79%/42.72%
# 116/200 | Cost: 161694.18 | Train/Valid Acc.: 37.74%/37.10%
# 117/200 | Cost: 161748.09 | Train/Valid Acc.: 31.25%/30.94%
# 118/200 | Cost: 161653.67 | Train/Valid Acc.: 37.99%/38.74%
# 119/200 | Cost: 161832.53 | Train/Valid Acc.: 37.31%/36.68%
# 120/200 | Cost: 161677.44 | Train/Valid Acc.: 38.56%/38.76%
# 121/200 | Cost: 161856.13 | Train/Valid Acc.: 36.44%/36.08%
# 122/200 | Cost: 161673.96 | Train/Valid Acc.: 38.39%/38.72%
# 123/200 | Cost: 161554.24 | Train/Valid Acc.: 34.93%/34.98%
# 124/200 | Cost: 161647.33 | Train/Valid Acc.: 33.63%/33.40%
# 125/200 | Cost: 161763.64 | Train/Valid Acc.: 40.82%/39.74%
# 126/200 | Cost: 161617.32 | Train/Valid Acc.: 35.34%/35.04%
# 127/200 | Cost: 161606.42 | Train/Valid Acc.: 37.05%/37.02%
# 128/200 | Cost: 161599.53 | Train/Valid Acc.: 36.58%/36.60%
# 129/200 | Cost: 161621.76 | Train/Valid Acc.: 34.86%/35.52%
# 130/200 | Cost: 161712.84 | Train/Valid Acc.: 33.58%/33.50%
# 131/200 | Cost: 161604.71 | Train/Valid Acc.: 37.62%/37.68%
# 132/200 | Cost: 161653.60 | Train/Valid Acc.: 42.55%/42.38%
# 133/200 | Cost: 161609.68 | Train/Valid Acc.: 37.62%/37.46%
# 134/200 | Cost: 161756.96 | Train/Valid Acc.: 37.32%/37.26%
# 135/200 | Cost: 161673.76 | Train/Valid Acc.: 43.25%/42.98%
# 136/200 | Cost: 161912.12 | Train/Valid Acc.: 40.32%/39.18%
# 137/200 | Cost: 161752.74 | Train/Valid Acc.: 39.98%/39.48%
# 138/200 | Cost: 161650.22 | Train/Valid Acc.: 42.31%/42.60%
# 139/200 | Cost: 161801.86 | Train/Valid Acc.: 33.20%/33.38%
# 140/200 | Cost: 161429.92 | Train/Valid Acc.: 35.32%/35.90%
# 141/200 | Cost: 161646.82 | Train/Valid Acc.: 38.84%/39.52%
# 142/200 | Cost: 161556.12 | Train/Valid Acc.: 34.37%/34.64%
# 143/200 | Cost: 161530.34 | Train/Valid Acc.: 40.53%/41.06%
# 144/200 | Cost: 161920.05 | Train/Valid Acc.: 39.51%/39.38%
# 145/200 | Cost: 161705.54 | Train/Valid Acc.: 37.88%/37.70%
# 146/200 | Cost: 161656.36 | Train/Valid Acc.: 34.82%/34.82%
# 147/200 | Cost: 161515.35 | Train/Valid Acc.: 38.09%/38.46%
# 148/200 | Cost: 161689.31 | Train/Valid Acc.: 35.11%/34.36%
# 149/200 | Cost: 161817.43 | Train/Valid Acc.: 45.18%/44.62%
# 150/200 | Cost: 161748.62 | Train/Valid Acc.: 41.59%/41.94%
# 151/200 | Cost: 161794.30 | Train/Valid Acc.: 43.19%/42.92%
# 152/200 | Cost: 161804.17 | Train/Valid Acc.: 35.82%/34.90%
# 153/200 | Cost: 161690.87 | Train/Valid Acc.: 35.61%/35.40%
# 154/200 | Cost: 161682.18 | Train/Valid Acc.: 35.83%/35.32%
# 155/200 | Cost: 161563.98 | Train/Valid Acc.: 33.41%/33.90%
# 156/200 | Cost: 161725.63 | Train/Valid Acc.: 40.54%/40.48%
# 157/200 | Cost: 161689.02 | Train/Valid Acc.: 36.25%/36.10%
# 158/200 | Cost: 161573.88 | Train/Valid Acc.: 30.94%/31.00%
# 159/200 | Cost: 161631.03 | Train/Valid Acc.: 41.21%/41.24%
# 160/200 | Cost: 161758.89 | Train/Valid Acc.: 33.70%/33.56%
# 161/200 | Cost: 161625.37 | Train/Valid Acc.: 35.50%/35.00%
# 162/200 | Cost: 161749.53 | Train/Valid Acc.: 37.12%/36.52%
# 163/200 | Cost: 161747.12 | Train/Valid Acc.: 43.98%/44.20%
# 164/200 | Cost: 161808.24 | Train/Valid Acc.: 37.68%/36.80%
# 165/200 | Cost: 161610.98 | Train/Valid Acc.: 33.14%/33.10%
# 166/200 | Cost: 161724.25 | Train/Valid Acc.: 36.61%/36.42%
# 167/200 | Cost: 161714.99 | Train/Valid Acc.: 40.47%/41.10%
# 168/200 | Cost: 161559.52 | Train/Valid Acc.: 40.87%/40.92%
# 169/200 | Cost: 161591.28 | Train/Valid Acc.: 40.51%/40.28%
# 170/200 | Cost: 161598.90 | Train/Valid Acc.: 37.04%/37.22%
# 171/200 | Cost: 161727.47 | Train/Valid Acc.: 40.68%/40.40%
# 172/200 | Cost: 161491.45 | Train/Valid Acc.: 37.55%/37.28%
# 173/200 | Cost: 161674.71 | Train/Valid Acc.: 34.39%/34.46%
# 174/200 | Cost: 161672.05 | Train/Valid Acc.: 40.87%/40.90%
# 175/200 | Cost: 161686.28 | Train/Valid Acc.: 37.00%/35.96%
# 176/200 | Cost: 161671.16 | Train/Valid Acc.: 39.84%/39.42%
# 177/200 | Cost: 161729.59 | Train/Valid Acc.: 40.75%/40.74%
# 178/200 | Cost: 161690.42 | Train/Valid Acc.: 34.05%/34.68%
# 179/200 | Cost: 161565.63 | Train/Valid Acc.: 39.02%/38.58%
# 180/200 | Cost: 161544.65 | Train/Valid Acc.: 35.04%/34.74%
# 181/200 | Cost: 161695.73 | Train/Valid Acc.: 34.47%/34.88%
# 182/200 | Cost: 161684.75 | Train/Valid Acc.: 36.13%/36.26%
# 183/200 | Cost: 161700.45 | Train/Valid Acc.: 33.82%/33.42%
# 184/200 | Cost: 161663.39 | Train/Valid Acc.: 38.98%/38.76%
# 185/200 | Cost: 161938.64 | Train/Valid Acc.: 46.35%/45.86%
# 186/200 | Cost: 161827.27 | Train/Valid Acc.: 36.69%/36.34%
# 187/200 | Cost: 161643.57 | Train/Valid Acc.: 43.91%/44.02%
# 188/200 | Cost: 161577.66 | Train/Valid Acc.: 40.24%/40.52%
# 189/200 | Cost: 161643.74 | Train/Valid Acc.: 37.93%/37.66%
# 190/200 | Cost: 161711.98 | Train/Valid Acc.: 37.51%/38.34%
# 191/200 | Cost: 161855.83 | Train/Valid Acc.: 41.73%/41.26%
# 192/200 | Cost: 161658.62 | Train/Valid Acc.: 37.86%/38.58%
# 193/200 | Cost: 161650.26 | Train/Valid Acc.: 43.62%/44.04%
# 194/200 | Cost: 161552.74 | Train/Valid Acc.: 35.68%/35.74%
# 195/200 | Cost: 161749.54 | Train/Valid Acc.: 40.80%/40.34%
# 196/200 | Cost: 161691.98 | Train/Valid Acc.: 36.19%/36.50%
# 197/200 | Cost: 161879.82 | Train/Valid Acc.: 35.35%/34.58%
# 198/200 | Cost: 161698.29 | Train/Valid Acc.: 40.05%/39.34%
# 199/200 | Cost: 161664.59 | Train/Valid Acc.: 35.65%/35.36%
# 200/200 | Cost: 161803.99 | Train/Valid Acc.: 33.48%/33.36%

# %% [markdown]
# ## Task 1 [60 marks]
#
# ### Part A: Optimize L2 Regularization
#
# In the provided code, an L2 regularization parameter, `l2`, was set to 10. Your task is to find the optimal value for `l2` that can improve the model's performance. After selecting the optimal `l2` value, report the following accuracies:
# - Training accuracy
# - Validation accuracy
# - Test accuracy
#
# Discuss in your report why these accuracies changed significantly when you experimented with different `l2` values. Hint: Try lower values of `l2`.
#
# ### Part B: Explore Activation Functions
#
# Modify the code to use different activation functions in the hidden layer, specifically `tanh` and `relu`. Keep the output layer activation function as `sigmoid` since the output needs to be in the range 0-1 for cross-entropy loss calculation. Use the previously optimized `l2` value for this part. Report the effects of using these activation functions on the training, validation, and test accuracies.
#
# Please provide detailed explanations of the observed changes in accuracy and any insights you gain from these experiments.

# %% [markdown]
# # Part A
# In order to determine a good value for the L2, I figured that a logarithmic approach in L2 would give me a rough estimate on where L2 should be found.
# I found the most optimal value to be at 0.001, anything smaller and there are diminishing returns.
# Training accuracy: Accuracy of the model on the training set.
# Validation accuracy: is used for hyperparameter tuning and preventing overfitting during training.
# Test accuracy: Completely new unseen data.
#
# The choice of the regularization parameter (l2) significantly influences the model's performance.
# When experimenting with different l2 values, the training, validation, and test accuracies varied.
# A higher l2 value (e.g., 10) led to stronger regularization, causing the model to generalize better
# on unseen data (test set). However, excessively high l2 values may result in underfitting.
# Conversely, lower l2 values (e.g., 0.001) allowed the model to fit the training data more closely,
# but this might lead to overfitting on the training set and reduced generalization on the validation
# and test sets.
#
# I found that for high values of L2, the accuracy of all values was poor and therefore not useful.
# Furthermore, for super low values of l2 the accuracy of all values was very good. However, this could suggest we were overfitting the data the smaller we went. Despite this validation and testing accuracy results were still quite high. The smaller we made L2, the effect on the relationship between testing, validation and training accuracies became a constant. However in the region between 0.005 and 0.075 we find that all values have a very similar yet high accuracy percentage. Therefore an optimal l2 value of 0.0075 strikes a balance, providing good generalization across all sets and achieving the best overall performance.
#
# # Exemplar and more technical:
#
# I observed that for high `l2` values (e.g., 10), the model's accuracy was poor, likely due to strong regularization that hindered the model's ability to capture the underlying patterns in the data. On the other hand, very low `l2` values resulted in very good accuracy, but this raised concerns about potential overfitting to the training data.
#
# When exploring the impact of `l2` in the range of 0.005 to 0.075, I noticed that all values within this range exhibited consistently high accuracy percentages across training, validation, and testing sets. This suggests that the model was robust within this range, showing a balanced ability to generalize well to unseen data.
#
# After careful consideration, I found that an `l2` value of 0.0075 struck the optimal balance. This value provided good generalization across all sets and yielded the best overall performance. It avoided the extreme cases of poor performance due to over-regularization or overfitting observed at higher and lower `l2` values, respectively.
#
# In summary, the choice of `l2` significantly influenced the model's ability to generalize, and the optimal value was identified by striking a balance between regularization and fitting the training data without overfitting.

# %% [markdown]
# ## Task 2 [40 marks]
#
# For this task, use the optimized `l2` value obtained from Task 1 and the `sigmoid` activation function for your model. This task focuses on evaluating the model's performance and reporting various metrics.
#
# ### Part A: Confusion Matrix
#
# Write code to display the confusion matrix of the test data. Include both the code and the generated figure in your report.
#
# ### Part B: Precision, Recall, and F1-Score Calculation
#
# Write code to estimate precision, recall, and F1-score for the test data, considering each class separately. Include both the code and the results in your report.
#
# Reminder: The formulas for these metrics are as follows:
#
# - Accuracy:
#   \begin{equation}
#       Accuracy = \frac{TN + TP}{TN + TP + FN + FP}
#   \end{equation}
#
# - Precision:
#   \begin{equation}
#       Precision = \frac{TP}{TP + FP}
#   \end{equation}
#
# - Recall:
#   \begin{equation}
#       Recall = \frac{TP}{TP + FN}
#   \end{equation}
#
# - F1-Score:
#   \begin{equation}
#       F1\text{-}score = \frac{2 \cdot (Precision \cdot Recall)}{Precision + Recall}
#   \end{equation}
#
# Where:
# - TN = True Negative
# - TP = True Positive
# - FN = False Negative
# - FP = False Positive
#
# For reference and a useful diagram, you can visit the Wikipedia page on [Precision and Recall](https://en.wikipedia.org/wiki/Precision_and_recall).
#
# Please ensure you provide both the code and the calculated results in your report for a comprehensive evaluation of the model's performance.
